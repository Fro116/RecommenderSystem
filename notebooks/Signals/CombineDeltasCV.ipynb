# %%
import functools
import os
import pickle
import random

import numpy as np
import pandas as pd
import scipy.stats as st
import statsmodels.formula.api as smf


@functools.wraps(smf.ols)
def lm(*args, **kwargs):
    return smf.ols(*args, **kwargs).fit()

# %%
recommendee = "Fro116"
confidence_interval = 0.95
delta_sources = ["item", "user"]  # "item", "user"
cross_validate = True  # if true, train linear model on out of sample data

# %%
os.chdir(f"../../data/deltas/{recommendee}")

# %%
def get_deltas(sources):
    deltas = []
    for i, source in enumerate(sources):
        delta = pickle.load(open(source, "rb"))
        delta = delta.rename({x: x + f"_{i}" for x in delta.columns}, axis=1)
        deltas.append(delta)
    return pd.concat(deltas, axis=1)

# %%
def clean_data(df):
    # fill missing data with reasonable defaults
    num_deltas = len([x for x in df.columns if "delta_var" in x])
    for i in range(num_deltas):
        df[f"delta_{i}"] = df[f"delta_{i}"].fillna(0)
        df[f"delta_var_{i}"] = df[f"delta_var_{i}"].fillna(df[f"delta_var_{i}"].max())
    return df

# %%
if cross_validate:
    train_df = get_deltas([f"{x}_oos.pkl" for x in delta_sources])
else:
    train_df = get_deltas([f"{x}_is.pkl" for x in delta_sources])
delta_corrs = train_df[[f"delta_{i}" for i in range(len(delta_sources))]].corr()

# %%
labelled_data = pickle.load(open("recommendee.pkl", "rb"))
labelled_data = clean_data(labelled_data.merge(train_df, on="anime_id"))

# %%
delta_corrs
# Out:
#           delta_0   delta_1
# delta_0  1.000000  0.603876
# delta_1  0.603876  1.000000

# %%
# get model
delta_cols = [f"delta_{i}" for i in range(len(delta_sources))]
formula = "normalized_score ~ 0 +" + " + ".join(delta_cols)
model = lm(formula, labelled_data)
print(model.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:       normalized_score   R-squared (uncentered):                   0.213
# Model:                            OLS   Adj. R-squared (uncentered):              0.209
# Method:                 Least Squares   F-statistic:                              50.18
# Date:                Sun, 16 May 2021   Prob (F-statistic):                    5.16e-20
# Time:                        10:41:42   Log-Likelihood:                         -675.07
# No. Observations:                 373   AIC:                                      1354.
# Df Residuals:                     371   BIC:                                      1362.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# delta_0        1.1699      0.224      5.223      0.000       0.729       1.610
# delta_1        1.2480      0.418      2.983      0.003       0.425       2.071
# ==============================================================================
# Omnibus:                       26.647   Durbin-Watson:                   1.961
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               31.834
# Skew:                          -0.608   Prob(JB):                     1.22e-07
# Kurtosis:                       3.755   Cond. No.                         2.85
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
df = clean_data(get_deltas([f"{x}_is.pkl" for x in delta_sources]))

# %%
blp = pickle.load(open("blp.pkl", "rb"))
df["blp"] = blp
df["score"] = model.predict(df) + df["blp"]
df["delta"] = df["score"] - df["blp"]

# %%
# compute error bars
model_vars = pd.DataFrame()
for col in delta_cols:
    i = col.split("_")[1]
    model_vars[f"model_delta_var_{i}"] = (
        (df[f"delta_var_{i}"] + df[f"delta_{i}"] ** 2)
        * (model.bse[f"delta_{i}"] ** 2 + model.params[f"delta_{i}"] ** 2)
    ) - df[f"delta_{i}"] ** 2 * model.params[f"delta_{i}"] ** 2
model_stds = np.sqrt(model_vars)

delta_corrs = delta_corrs.loc[lambda x: (x.index.isin(delta_cols)), delta_cols]
delta_variance = np.sum(
    (model_stds.values @ delta_corrs.values) * model_stds.values, axis=1
)
intercept_variance = 0
if "Intercept" in model.bse:
    intercept_variance = model.bse["Intercept"] ** 2
df["std"] = np.sqrt(delta_variance + intercept_variance)

zscore = st.norm.ppf(1 - (1 - confidence_interval) / 2)
df["score_lower_bound"] = df["score"] - df["std"] * zscore
df["score_upper_bound"] = df["score"] + df["std"] * zscore
# Out:
# <ipython-input-12-dc42af8cba78>:13: RuntimeWarning: invalid value encountered in matmul
#   (model_stds.values @ delta_corrs.values) * model_stds.values, axis=1

# %%
anime = pd.read_csv("../../AnimeList.csv")
anime = anime[["anime_id", "title", "type"]]
df = df.merge(anime, on="anime_id").set_index("anime_id")

# %%
# reorder the columns
cols = [
    "title",
    "type",
    "score",
    "score_lower_bound",
    "score_upper_bound",
    "delta",
    "std",
] + delta_cols
df = df[cols + [x for x in df.columns if x not in cols]]

# %%
related_series = pickle.load(open("../../anime_facts/related_series.pkl", "rb"))
df = df.merge(related_series, on="anime_id").set_index("anime_id")

# %%
new_recs = df.loc[lambda x: ~x.index.isin(labelled_data.anime_id) & (x["type"] == "TV")]

# %%
df.loc[lambda x: (x["delta"] > 0)].sort_values(by="score_lower_bound", ascending=False)[
    :20
]
# Out:
#                                                       title     type  \
# anime_id
# 3297                                   Aria The Origination       TV
# 32           Neon Genesis Evangelion: The End of Evangelion    Movie
# 820                                    Ginga Eiyuu Densetsu      OVA
# 3784                  Evangelion: 2.0 You Can (Not) Advance    Movie
# 34376     Yuuki Yuuna wa Yuusha de Aru: Washio Sumi no S...    Movie
# 30                                  Neon Genesis Evangelion       TV
# 962                                        Aria The Natural       TV
# 34375     Yuuki Yuuna wa Yuusha de Aru: Washio Sumi no S...    Movie
# 11981     Mahou Shoujo Madoka★Magica Movie 3: Hangyaku n...    Movie
# 11979     Mahou Shoujo Madoka★Magica Movie 2: Eien no Mo...    Movie
# 9756                             Mahou Shoujo Madoka★Magica       TV
# 397                                      Seikai no Senki II       TV
# 2563                                  Aria The OVA: Arietta      OVA
# 9617                                            K-On! Movie    Movie
# 2759                    Evangelion: 1.0 You Are (Not) Alone    Movie
# 29893                                     Aria The Avvenire  Special
# 396                                         Seikai no Senki       TV
# 849                              Suzumiya Haruhi no Yuuutsu       TV
# 4772      Aria The Origination: Sono Choppiri Himitsu no...  Special
# 11977     Mahou Shoujo Madoka★Magica Movie 1: Hajimari n...    Movie
#
#              score  score_lower_bound  score_upper_bound     delta       std  \
# anime_id
# 3297      8.540956           7.472542           9.609370  0.976059  0.545119
# 32        8.551180           7.316574           9.785786  1.313252  0.629913
# 820       8.219784           7.265892           9.173676  0.433637  0.486688
# 3784      8.111472           7.258130           8.964813  0.651820  0.435386
# 34376     9.421861           7.220235          11.623487  2.414868  1.123299
# 23269     0.097456     0.065329     0.020346  6.486389       5068
# 85        0.144790     0.080153     0.044852  6.825587         51
# 3750     -0.124785     0.092832     0.050255  6.925994        102
# 1065      0.011101     0.096628     0.078891  6.925062        693
# 122       0.012042     0.123531     0.036636  6.850261         74
# 1852      0.173589     0.034359     0.016621  6.308360       1143
# 35240     0.035143     0.046819     0.015701  6.428120       8909
# 32526     0.077840     0.093024     0.020120  6.284532       4084
# 35241     0.025248     0.072313     0.036283  6.393960       8910
# 95        0.259776     0.079342     0.065335  6.487560         51
# 31771     0.275771     0.034315     0.020682  6.192476       7657
# 147       0.124684     0.043462     0.008324  6.276708         91
# 31706    -0.015857     0.069980     0.024533  6.455045        265
# 2921      0.283397     0.094440     0.205213  7.460817       1482
# 21273     0.053971     0.063994     0.011620  6.357192       5698

# %%
new_recs.loc[lambda x: (x["delta_0"] < 0) & (x["delta_1"] > 0)].sort_values(
    by="score_lower_bound", ascending=False
)[:20]
# Out:
#                                               title type     score  \
# anime_id
# 85                          Mobile Suit Zeta Gundam   TV  6.997794
# 182                            Tenkuu no Escaflowne   TV  6.589693
# 1453                                  Maison Ikkoku   TV  6.983249
# 31771                                      Amanchu!   TV  6.536529
# 147                             Kimi ga Nozomu Eien   TV  6.414748
# 2921                                Ashita no Joe 2   TV  7.464072
# 2402                                  Ashita no Joe   TV  7.191851
# 26                                       Texhnolyze   TV  6.405625
# 80                               Mobile Suit Gundam   TV  6.709501
# 26165                              Yuri Kuma Arashi   TV  6.226857
# 32681                           Uchuu Patrol Luluco   TV  6.230154
# 1454                                     Kemonozume   TV  6.177294
# 32607                             Gi(a)rlish Number   TV  6.013983
# 369       Boogiepop wa Warawanai: Boogiepop Phantom   TV  6.034443
# 567                                       The Big O   TV  6.181628
# 9996                                    Hyouge Mono   TV  6.740029
# 878                                        Zegapain   TV  6.410337
# 16051                                 Ro-Kyu-Bu! SS   TV  6.466534
# 874                                  Digimon Tamers   TV  6.201938
# 469                                           Karin   TV  6.141448
#
#           score_lower_bound  score_upper_bound     delta       std   delta_0  \
# anime_id
# 85                 5.904261           8.091328  0.172207  0.557935 -0.007264
# 182                5.833683           7.345702 -0.017690  0.385726 -0.058731
# 1453               5.803496           8.163002 -0.030707  0.601926 -0.063060
# 31771              5.760160           7.312898  0.344053  0.396114 -0.000105
# 147                5.741225           7.088271  0.138040  0.343641 -0.015020
# 2921               5.731568           9.196576  0.003255  0.883947 -0.299554
# 2402               5.702906           8.680797  0.292037  0.759680 -0.172064
# 26                 5.689446           7.121805 -0.022164  0.365405 -0.255894
# 80                 5.686195           7.732806  0.042484  0.522104 -0.121945
# 26165              5.381944           7.071771  0.417619  0.431086 -0.056350
# 32681              5.344072           7.116237 -0.062698  0.452091 -0.354357
# 1454               5.289701           7.064888 -0.106846  0.452862 -0.276624
# 32607              5.220929           6.807037  0.172611  0.404627 -0.074711
# 369                5.203350           6.865535  0.012944  0.424034 -0.131975
# 567                5.192975           7.170280 -0.132752  0.504424 -0.186919
# 9996               5.189235           8.290824  0.280087  0.791236 -0.291126
# 878                5.136113           7.684560  0.127003  0.650126 -0.150485
# 16051              5.132120           7.800947  0.301330  0.680836 -0.103044
# 874                5.131397           7.272480 -0.107285  0.546205 -0.118131
# 469                5.129071           7.153826 -0.116189  0.516529 -0.165926
#
#            delta_1  delta_var_0  delta_var_1       blp  series_id
# anime_id
# 85        0.144790     0.080153     0.044852  6.825587         51
# 182       0.040878     0.046723     0.016660  6.607382        124
# 1453      0.034506     0.108358     0.044287  7.013956        894
# 31771     0.275771     0.034315     0.020682  6.192476       7657
# 147       0.124684     0.043462     0.008324  6.276708         91
# 2921      0.283397     0.094440     0.205213  7.460817       1482
# 2402      0.395281     0.103870     0.107229  6.899814       1482
# 26        0.222104     0.037665     0.011384  6.427790         16
# 80        0.148346     0.081311     0.031058  6.667017         51
# 26165     0.387438     0.041349     0.017762  5.809238       6441
# 32681     0.281922     0.061880     0.013925  6.292853       7908
# 1454      0.173685     0.052422     0.026253  6.284140        895
# 32607     0.208335     0.040794     0.021171  5.841372       7877
# 369       0.134079     0.042304     0.027830  6.021499        276
# 567       0.068842     0.072958     0.031985  6.314380        403
# 9996      0.497309     0.097837     0.121124  6.459942       4121
# 878       0.242820     0.120971     0.048927  6.283333        590
# 16051     0.338030     0.144390     0.041595  6.165203       4270
# 874       0.024768     0.127296     0.016782  6.309223        586
# 469       0.062434     0.105601     0.017972  6.257638        332

# %%
new_recs.loc[lambda x: (x["delta_0"] > 0) & (x["delta_1"] < 0)].sort_values(
    by="score_lower_bound", ascending=False
)[:20]
# Out:
#                                               title type     score  \
# anime_id
# 34914                                    New Game!!   TV  6.928738
# 30279                            Yuru Yuri San☆Hai!   TV  6.854327
# 19111     Love Live! School Idol Project 2nd Season   TV  6.959401
# 427                                    Kaleido Star   TV  7.211081
# 3750                       Maria-sama ga Miteru 4th   TV  7.062796
# 30727                Saenai Heroine no Sodatekata ♭   TV  6.540713
# 31706         Fate/kaleid liner Prisma☆Illya 3rei!!   TV  6.661921
# 2986                                   Bamboo Blade   TV  6.507504
# 10278                                The iDOLM@STER   TV  6.367018
# 1974                          Glass no Kamen (2005)   TV  7.081965
# 1222                                  Bokura ga Ita   TV  6.424937
# 20509          Fate/kaleid liner Prisma☆Illya 2wei!   TV  6.418848
# 5671                                           Saki   TV  6.369316
# 35860                   Karakai Jouzu no Takagi-san   TV  6.464658
# 2035        Eikoku Koi Monogatari Emma: Molders-hen   TV  6.771877
# 15731                     Tamayura: More Aggressive   TV  6.763233
# 16732                                 Kiniro Mosaic   TV  6.315446
# 33988                        Demi-chan wa Kataritai   TV  6.283968
# 957                            Saiunkoku Monogatari   TV  6.860225
# 31952           Kono Bijutsubu ni wa Mondai ga Aru!   TV  6.307438
#
#           score_lower_bound  score_upper_bound     delta       std   delta_0  \
# anime_id
# 34914              6.166266           7.691210  0.162377  0.389023  0.163180
# 30279              6.063762           7.644892 -0.018147  0.403357  0.055982
# 19111              6.045935           7.872868  0.120971  0.466063  0.199912
# 427                6.014530           8.407632  0.353094  0.610496  0.402852
# 3750               5.890836           8.234757  0.136802  0.597950  0.250062
# 30727              5.815138           7.266288 -0.133184  0.370198  0.003351
# 31706              5.736454           7.587389  0.206876  0.472186  0.193754
# 2986               5.707550           7.307458  0.137259  0.408147  0.170997
# 10278              5.648128           7.085908 -0.132620  0.366787  0.015037
# 1974               5.635505           8.528425  0.051013  0.738003  0.101163
# 1222               5.626665           7.223208  0.060692  0.407289  0.057148
# 20509              5.615557           7.222139  0.144523  0.409850  0.154928
# 5671               5.597581           7.141050 -0.020814  0.393749  0.061135
# 35860              5.579145           7.350172 -0.086233  0.451801  0.073729
# 2035               5.577461           7.966294 -0.187677  0.609407  0.051838
# 15731              5.566210           7.960257  0.363015  0.610737  0.339336
# 16732              5.525757           7.105135  0.091039  0.402910  0.093062
# 33988              5.520305           7.047630 -0.299484  0.389631  0.028720
# 957                5.511314           8.209136 -0.011446  0.688233  0.154700
# 31952              5.507034           7.107843  0.078748  0.408377  0.112615
#
#            delta_1  delta_var_0  delta_var_1       blp  series_id
# anime_id
# 34914    -0.022853     0.046156     0.017397  6.766361       7708
# 30279    -0.067015     0.055767     0.015284  6.872475       4245
# 19111    -0.090461     0.091230     0.011599  6.838430       4084
# 427      -0.094699     0.104251     0.045804  6.857987        315
# 3750     -0.124785     0.092832     0.050255  6.925994        102
# 30727    -0.109855     0.046328     0.012445  6.673897       6028
# 31706    -0.015857     0.069980     0.024533  6.455045        265
# 2986     -0.050306     0.052305     0.018056  6.370245       1842
# 10278    -0.120357     0.039500     0.015522  6.499638       1044
# 1974     -0.053951     0.153183     0.072656  7.030952       1210
# 1222     -0.004939     0.060797     0.013973  6.364245        792
# 20509    -0.029423     0.062262     0.013353  6.274325        265
# 5671     -0.073983     0.053608     0.014176  6.390129       2952
# 35860    -0.138205     0.072013     0.016687  6.550892       9175
# 2035     -0.198967     0.095456     0.052091  6.959555        257
# 15731    -0.027213     0.106754     0.046194  6.400218       3859
# 16732    -0.014287     0.064102     0.011353  6.224407       5068
# 33988    -0.266882     0.049682     0.008851  6.583451       8404
# 957      -0.154180     0.165335     0.041525  6.871671        628
# 31952    -0.042463     0.063660     0.012461  6.228691       7707

# %%
new_recs.loc[lambda x: (x["delta_0"] > 0) & (x["delta_1"] > 0)].sort_values(
    by="score_lower_bound", ascending=False
)[:20]
# Out:
#                                      title type     score  score_lower_bound  \
# anime_id
# 7062                 Hidamari Sketch x ☆☆☆   TV  7.151099           6.350553
# 3604                 Hidamari Sketch x 365   TV  7.070441           6.291381
# 29787         Gochuumon wa Usagi desu ka??   TV  7.084320           6.249047
# 11239          Hidamari Sketch x Honeycomb   TV  7.117378           6.242418
# 444             Maria-sama ga Miteru: Haru   TV  7.244508           6.159405
# 1088                               Macross   TV  7.056986           6.116359
# 34973     Love Live! Sunshine!! 2nd Season   TV  7.353952           6.089932
