# %%
import functools
import os
import pickle
import random

import numpy as np
import pandas as pd
import scipy.stats as st
import statsmodels.formula.api as smf


@functools.wraps(smf.ols)
def lm(*args, **kwargs):
    return smf.ols(*args, **kwargs).fit()

# %%
recommendee = "Fro116"
confidence_interval = 0.99
delta_sources = ["item", "user"]  # "item", "user"
cross_validate = True  # if true, train linear model on out of sample data

# %%
os.chdir(f"../../data/deltas/{recommendee}")

# %%
def get_deltas(sources):
    deltas = []
    for i, source in enumerate(sources):
        delta = pickle.load(open(source, "rb"))
        delta = delta.rename({x: x + f"_{i}" for x in delta.columns}, axis=1)
        deltas.append(delta)
    return pd.concat(deltas, axis=1)

# %%
def clean_data(df):
    # fill missing data with reasonable defaults
    num_deltas = len([x for x in df.columns if "delta_var" in x])
    for i in range(num_deltas):
        df[f"delta_{i}"] = df[f"delta_{i}"].fillna(0)
        df[f"delta_var_{i}"] = df[f"delta_var_{i}"].fillna(df[f"delta_var_{i}"].max())
    return df

# %%
if cross_validate:
    train_df = get_deltas([f"{x}_oos.pkl" for x in delta_sources])
else:
    train_df = get_deltas([f"{x}_is.pkl" for x in delta_sources])
delta_corrs = train_df[[f"delta_{i}" for i in range(len(delta_sources))]].corr()

# %%
labelled_data = pickle.load(open("recommendee.pkl", "rb"))
labelled_data = clean_data(labelled_data.merge(train_df, on="anime_id"))

# %%
delta_corrs
# Out:
#           delta_0   delta_1
# delta_0  1.000000  0.552765
# delta_1  0.552765  1.000000

# %%
# get model
delta_cols = [f"delta_{i}" for i in range(len(delta_sources))]
formula = "normalized_score ~ 0 +" + " + ".join(delta_cols)
model = lm(formula, labelled_data)
print(model.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:       normalized_score   R-squared (uncentered):                   0.247
# Model:                            OLS   Adj. R-squared (uncentered):              0.243
# Method:                 Least Squares   F-statistic:                              61.14
# Date:                Thu, 06 May 2021   Prob (F-statistic):                    1.08e-23
# Time:                        23:00:42   Log-Likelihood:                         -658.60
# No. Observations:                 375   AIC:                                      1321.
# Df Residuals:                     373   BIC:                                      1329.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# delta_0        0.7020      0.116      6.033      0.000       0.473       0.931
# delta_1        1.3373      0.337      3.964      0.000       0.674       2.001
# ==============================================================================
# Omnibus:                       41.179   Durbin-Watson:                   1.910
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               62.439
# Skew:                          -0.719   Prob(JB):                     2.76e-14
# Kurtosis:                       4.390   Cond. No.                         3.74
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
df = clean_data(get_deltas([f"{x}_is.pkl" for x in delta_sources]))

# %%
blp = pickle.load(open("blp.pkl", "rb"))
df["blp"] = blp
df["score"] = model.predict(df) + df["blp"]
df["delta"] = df["score"] - df["blp"]

# %%
# compute error bars
model_vars = pd.DataFrame()
for col in delta_cols:
    i = col.split("_")[1]
    model_vars[f"model_delta_var_{i}"] = (
        (df[f"delta_var_{i}"] + df[f"delta_{i}"] ** 2)
        * (model.bse[f"delta_{i}"] ** 2 + model.params[f"delta_{i}"] ** 2)
    ) - df[f"delta_{i}"] ** 2 * model.params[f"delta_{i}"] ** 2
model_stds = np.sqrt(model_vars)

delta_corrs = delta_corrs.loc[lambda x: (x.index.isin(delta_cols)), delta_cols]
delta_variance = np.sum(
    (model_stds.values @ delta_corrs.values) * model_stds.values, axis=1
)
intercept_variance = 0
if "Intercept" in model.bse:
    intercept_variance = model.bse["Intercept"] ** 2
df["std"] = np.sqrt(delta_variance + intercept_variance)

zscore = st.norm.ppf(1 - (1 - confidence_interval) / 2)
df["score_lower_bound"] = df["score"] - df["std"] * zscore
df["score_upper_bound"] = df["score"] + df["std"] * zscore
# Out:
# <ipython-input-12-dc42af8cba78>:13: RuntimeWarning: invalid value encountered in matmul
#   (model_stds.values @ delta_corrs.values) * model_stds.values, axis=1

# %%
anime = pd.read_csv("../../AnimeList.csv")
anime = anime[["anime_id", "title", "type"]]
df = df.merge(anime, on="anime_id").set_index("anime_id")

# %%
df.head()
# Out:
#            delta_0  delta_var_0   delta_1  delta_var_1       blp     score  \
# anime_id
# 1        -0.467249     0.085123 -0.181562     0.003305  7.646973  7.076186
# 5        -0.583070     0.113083 -0.220424     0.006535  7.304627  6.600570
# 6        -0.374968     0.137050 -0.389742     0.005290  7.170132  6.385725
# 7        -0.071229     0.530290 -0.258158     0.029067  6.253132  5.857901
# 8         0.000000          inf  0.306084     0.370442  5.947662  6.356984
#
#              delta       std  score_lower_bound  score_upper_bound  \
# anime_id
# 1        -0.570787  0.282601           6.348255           7.804117
# 5        -0.704057  0.341563           5.720761           7.480379
# 6        -0.784407  0.384008           5.396586           7.374863
# 7        -0.395231  0.689256           4.082496           7.633305
# 8         0.409323       inf               -inf                inf
#
#                                     title   type
# anime_id
# 1                            Cowboy Bebop     TV
# 5         Cowboy Bebop: Tengoku no Tobira  Movie
# 6                                  Trigun     TV
# 7                      Witch Hunter Robin     TV
# 8                  Beet the Vandel Buster     TV

# %%
# reorder the columns
cols = [
    "title",
    "type",
    "score",
    "score_lower_bound",
    "score_upper_bound",
    "delta",
    "std",
] + delta_cols
df = df[cols + [x for x in df.columns if x not in cols]]

# %%
new_recs = df.loc[lambda x: ~x.index.isin(labelled_data.anime_id) & (x["type"] == "TV")]

# %%
df.loc[lambda x: (x["delta"] > 0)].sort_values(
    by="score_lower_bound", ascending=False
)[:20]
# Out:
#                                                       title     type  \
# anime_id
# 3297                                   Aria The Origination       TV
# 32           Neon Genesis Evangelion: The End of Evangelion    Movie
# 3784                  Evangelion: 2.0 You Can (Not) Advance    Movie
# 30                                  Neon Genesis Evangelion       TV
# 962                                        Aria The Natural       TV
# 2001                             Tengen Toppa Gurren Lagann       TV
# 11981     Mahou Shoujo Madoka★Magica Movie 3: Hangyaku n...    Movie
# 820                                    Ginga Eiyuu Densetsu      OVA
# 2759                    Evangelion: 1.0 You Are (Not) Alone    Movie
# 2563                                  Aria The OVA: Arietta      OVA
# 34376     Yuuki Yuuna wa Yuusha de Aru: Washio Sumi no S...    Movie
# 397                                      Seikai no Senki II       TV
# 11979     Mahou Shoujo Madoka★Magica Movie 2: Eien no Mo...    Movie
# 29893                                     Aria The Avvenire  Special
# 9756                             Mahou Shoujo Madoka★Magica       TV
# 396                                         Seikai no Senki       TV
# 4772      Aria The Origination: Sono Choppiri Himitsu no...  Special
# 31500              5.540930           9.381019  1.328938  0.745408  1.586475
#
#            delta_1  delta_var_0  delta_var_1       blp
# anime_id
# 444       0.128683     0.177110     0.055514  6.854018
# 3604      0.100457     0.183315     0.030554  6.864584
# 593       0.353457     0.179988     0.056630  6.550637
# 153      -0.177403     0.107751     0.019091  7.003291
# 158       0.186946     0.148513     0.042268  6.411599
# 3750     -0.077997     0.269040     0.059885  7.006630
# 488      -0.003993     0.144166     0.020661  6.745950
# 21       -0.132399     0.455055     0.008786  7.421893
# 7062      0.028248     0.208271     0.035696  6.993135
# 182       0.057038     0.118342     0.022051  6.688018
# 2158     -0.131557     0.131132     0.036298  7.028426
# 11239     0.085342     0.219284     0.058336  6.941642
# 1852      0.135601     0.143081     0.021880  6.388996
# 427      -0.110140     0.284353     0.056815  6.938623
# 1088      0.067022     0.423378     0.033856  6.930418
# 34973     0.281741     0.600180     0.051900  6.537682
# 31771     0.234551     0.184533     0.031352  6.273112
# 32836     0.383268     0.710857     0.150842  6.359857
# 31706     0.090955     0.609913     0.037985  6.535681
# 165      -0.106843     0.144556     0.018587  6.470629
# 35240     0.021308     0.194428     0.020564  6.508755
# 2942      0.122847     0.170060     0.051887  6.367364
# 32681     0.331727     0.146705     0.018229  6.373488
# 26        0.205859     0.095917     0.014538  6.508426
# 85        0.150644     0.884572     0.041039  6.906223
# 1858      0.089808     0.239919     0.058225  6.368941
# 2986     -0.001348     0.132248     0.023487  6.450881
# 2403      0.330420     0.606063     0.020093  6.071553
# 21573     0.196360     1.031120     0.081566  6.288772
# 31500     0.161004     0.566350     0.035046  6.132036

# %%
new_recs.loc[lambda x: (x["delta_0"] < 0) & (x["delta_1"] > 0)].sort_values(
    by="score_lower_bound", ascending=False
)[:20]
# Out:
#                                               title type     score  \
# anime_id
# 32681                           Uchuu Patrol Luluco   TV  6.711765
# 26                                       Texhnolyze   TV  6.516369
# 634                                        Koi Kaze   TV  6.481841
# 147                             Kimi ga Nozomu Eien   TV  6.319061
# 33089                                Kemono Friends   TV  7.020587
# 4981                                  Casshern Sins   TV  6.199618
# 5074                       Tetsuwan Birdy Decode:02   TV  6.782362
# 21273                   Gochuumon wa Usagi desu ka?   TV  6.442806
# 1454                                     Kemonozume   TV  6.257140
# 2402                                  Ashita no Joe   TV  7.256177
# 14131                                Girls & Panzer   TV  6.297335
# 5597                               Natsu no Arashi!   TV  6.435075
# 369       Boogiepop wa Warawanai: Boogiepop Phantom   TV  6.053766
# 2921                                Ashita no Joe 2   TV  7.645100
# 23269                         Hello!! Kiniro Mosaic   TV  6.421953
# 34494                                  Sakura Quest   TV  6.242155
# 21039                      Gatchaman Crowds Insight   TV  6.205569
# 20057                                   Space☆Dandy   TV  5.748494
# 17741                             Kimi no Iru Machi   TV  6.013928
# 9996                                    Hyouge Mono   TV  6.879840
#
#           score_lower_bound  score_upper_bound     delta       std   delta_0  \
# anime_id
# 32681              5.596783           7.826746  0.338276  0.432863 -0.150064
# 26                 5.595586           7.437152  0.007943  0.357471 -0.380866
# 634                5.467052           7.496630  0.213504  0.393966 -0.077875
# 147                5.287068           7.351054 -0.038282  0.400645 -0.184693
# 33089              5.247220           8.793955  0.613971  0.688465 -0.060238
# 4981               5.211671           7.187565 -0.311254  0.383545 -0.539347
# 5074               5.207405           8.357320  0.003853  0.611437 -0.076359
# 21273              5.186922           7.698691  0.004978  0.487565 -0.025788
# 1454               5.024481           7.489800 -0.107635  0.478549 -0.666587
# 2402               5.017904           9.494451  0.275728  0.868953 -0.299183
# 14131              4.994063           7.600608 -0.237100  0.505962 -0.505870
# 5597               4.943967           7.926183  0.220591  0.578885 -0.053873
# 369                4.890851           7.216681 -0.048368  0.451472 -0.473220
# 2921               4.874419          10.415781  0.103648  1.075646 -0.204508
# 23269              4.867697           7.976209 -0.145072  0.603400 -0.292178
# 34494              4.792963           7.691346 -0.026700  0.562612 -0.231755
# 21039              4.750591           7.660546 -0.093746  0.564858 -0.353054
# 20057              4.748375           6.748614 -0.812520  0.388271 -1.174354
# 17741              4.674900           7.352955  0.123672  0.519843 -0.011599
# 9996               4.654910           9.104770  0.339262  0.863772 -0.690179
#
#            delta_1  delta_var_0  delta_var_1       blp
# anime_id
# 32681     0.331727     0.146705     0.018229  6.373488
# 26        0.205859     0.095917     0.014538  6.508426
# 634       0.200532     0.105140     0.022156  6.268336
# 147       0.068320     0.177188     0.011066  6.357343
# 33089     0.490736     0.419147     0.038355  6.406617
# 4981      0.050357     0.112550     0.018290  6.510872
# 5074      0.042962     0.247056     0.060703  6.778510
# 21273     0.017259     0.272714     0.015391  6.437828
# 1454      0.269408     0.139742     0.032858  6.364776
# 2402      0.363228     0.392872     0.144073  6.980449
# 14131     0.088236     0.306001     0.013351  6.534435
# 5597      0.193232     0.239091     0.047855  6.214484
# 369       0.212227     0.101403     0.038117  6.102134
# 2921      0.184854     0.373164     0.311282  7.541452
# 23269     0.044884     0.389314     0.027618  6.567025
# 34494     0.101684     0.276286     0.035080  6.268855
# 21039     0.115219     0.240343     0.043100  6.299314
# 20057     0.008839     0.127121     0.011176  6.561014
# 17741     0.098568     0.275495     0.022590  5.890256
# 9996      0.615974     0.272388     0.162558  6.540578

# %%
new_recs.loc[lambda x: (x["delta_0"] > 0) & (x["delta_1"] < 0)].sort_values(
    by="score_lower_bound", ascending=False
)[:20]
# Out:
#                                             title type     score  \
# anime_id
# 2164                                  Dennou Coil   TV  7.020057
# 18195                    Little Busters!: Refrain   TV  7.091152
# 153                                  Juuni Kokuki   TV  7.064283
# 3750                     Maria-sama ga Miteru 4th   TV  7.694776
# 488                              Ichigo Mashimaro   TV  7.085163
# 21                                      One Piece   TV  7.443730
# 16706        Kami nomi zo Shiru Sekai: Megami-hen   TV  7.016893
# 23623                       Non Non Biyori Repeat   TV  7.165178
# 2158                              Terra e... (TV)   TV  7.080248
# 427                                  Kaleido Star   TV  7.471613
# 16049                   Toaru Kagaku no Railgun S   TV  6.844064
# 165                                     RahXephon   TV  6.792783
# 2986                                 Bamboo Blade   TV  6.627904
# 59                                        Chobits   TV  6.510544
# 11433                        Ano Natsu de Matteru   TV  6.221750
# 36220     Itsudatte Bokura no Koi wa 10 cm Datta.   TV  7.240392
# 30727              Saenai Heroine no Sodatekata ♭   TV  6.588107
# 345                    Eikoku Koi Monogatari Emma   TV  6.663910
# 23277                Saenai Heroine no Sodatekata   TV  6.369554
# 15731                   Tamayura: More Aggressive   TV  6.937055
#
#           score_lower_bound  score_upper_bound     delta       std   delta_0  \
# anime_id
# 2164               6.215939           7.824175 -0.066870  0.312178  0.016037
# 18195              6.089320           8.092983 -0.164334  0.388935  0.183485
# 153                6.067965           8.060601  0.060991  0.386795  0.424859
# 3750               6.036050           9.353503  0.688146  0.643958  1.128924
# 488                6.004322           8.166003  0.339213  0.419609  0.490848
# 21                 5.979970           8.907490  0.021837  0.568268  0.283343
# 16706              5.946582           8.087204 -0.246828  0.415521  0.065404
# 23623              5.943401           8.386955 -0.016479  0.474324  0.084564
# 2158               5.884360           8.276136  0.051821  0.464273  0.324454
# 427                5.820461           9.122764  0.532990  0.641017  0.969124
# 16049              5.777540           7.910587 -0.261555  0.414051  0.014830
# 165                5.714248           7.871317  0.322153  0.418714  0.662486
# 2986               5.555393           7.700414  0.177023  0.416375  0.254754
# 59                 5.457067           7.564021  0.009012  0.408986  0.252645
# 11433              5.387088           7.056411 -0.347880  0.324036  0.035914
# 36220              5.301019           9.179765  0.860987  0.752912  1.576016
# 30727              5.298574           7.877640 -0.166426  0.500628  0.114390
# 345                5.270844           8.056977 -0.070259  0.540822  0.344976
# 23277              5.259893           7.479216 -0.170711  0.430798  0.202079
# 15731              5.255499           8.618612  0.456201  0.652821  0.671115
#
#            delta_1  delta_var_0  delta_var_1       blp
# anime_id
# 2164     -0.058422     0.076601     0.012704  7.086927
# 18195    -0.219199     0.144790     0.011643  7.255486
# 153      -0.177403     0.107751     0.019091  7.003291
# 3750     -0.077997     0.269040     0.059885  7.006630
# 488      -0.003993     0.144166     0.020661  6.745950
# 21       -0.132399     0.455055     0.008786  7.421893
# 16706    -0.218904     0.205745     0.007176  7.263721
# 23623    -0.056711     0.274946     0.011924  7.181657
# 2158     -0.131557     0.131132     0.036298  7.028426
# 427      -0.110140     0.284353     0.056815  6.938623
# 16049    -0.203370     0.193148     0.009181  7.105618
# 165      -0.106843     0.144556     0.018587  6.470629
# 2986     -0.001348     0.132248     0.023487  6.450881
# 59       -0.125876     0.208114     0.007347  6.501532
# 11433    -0.278990     0.097779     0.006050  6.569630
# 36220    -0.183432     0.507930     0.047222  6.379405
# 30727    -0.184494     0.258406     0.018886  6.754533
# 345      -0.233619     0.183811     0.045992  6.734170
# 23277    -0.233727     0.224446     0.006923  6.540266
# 15731    -0.011134     0.313639     0.058575  6.480854

# %%
new_recs.loc[lambda x: (x["delta_0"] > 0) & (x["delta_1"] > 0)].sort_values(
    by="score_lower_bound", ascending=False
)[:20]
# Out:
#                                           title type     score  \
# anime_id
# 444                  Maria-sama ga Miteru: Haru   TV  7.769043
# 3604                      Hidamari Sketch x 365   TV  7.445105
# 593                             Mugen no Ryvius   TV  7.686111
# 158                        Maria-sama ga Miteru   TV  7.399714
# 7062                      Hidamari Sketch x ☆☆☆   TV  7.308623
# 182                        Tenkuu no Escaflowne   TV  6.984104
