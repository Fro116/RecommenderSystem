# %%
import functools
import os
import pickle
import random

import numpy as np
import pandas as pd
import scipy.stats as st
import statsmodels.formula.api as smf


@functools.wraps(smf.ols)
def lm(*args, **kwargs):
    return smf.ols(*args, **kwargs).fit()

# %%
recommendee = "Fro116"
confidence_interval = 0.99
delta_sources = ["item", "user"]
cross_validate = False # if true, train linear model on out of sample data

# %%
os.chdir(f"../../data/deltas/{recommendee}")

# %%
def get_deltas(sources):
    deltas = []
    for i, source in enumerate(sources):
        delta = pickle.load(open(source, "rb"))
        delta = delta.rename({x: x + f"_{i}" for x in delta.columns}, axis=1)
        deltas.append(delta)
    return pd.concat(deltas, axis=1)

# %%
def clean_data(df):
    # fill missing data with reasonable defaults
    num_deltas = len([x for x in df.columns if "delta_var" in x])
    for i in range(num_deltas):
        df[f"delta_{i}"] = df[f"delta_{i}"].fillna(0)
        df[f"delta_var_{i}"] = df[f"delta_var_{i}"].fillna(df[f"delta_var_{i}"].max())
    return df

# %%
if cross_validate:
    train_df = get_deltas([f"{x}_oos.pkl" for x in delta_sources])
else:
    train_df = get_deltas([f"{x}_is.pkl" for x in delta_sources])  
delta_corrs = train_df[[f"delta_{i}" for i in range(len(delta_sources))]].corr()

# %%
labelled_data = pickle.load(open("recommendee.pkl", "rb"))
labelled_data = clean_data(labelled_data.merge(train_df, on="anime_id"))

# %%
delta_corrs
# Out:
#           delta_0   delta_1
# delta_0  1.000000  0.560888
# delta_1  0.560888  1.000000

# %%
# get model
delta_cols = [f"delta_{i}" for i in range(len(delta_sources))]
formula = "normalized_score ~ 0 +" + " + ".join(delta_cols)
model = lm(formula, labelled_data)
print(model.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:       normalized_score   R-squared (uncentered):                   0.251
# Model:                            OLS   Adj. R-squared (uncentered):              0.247
# Method:                 Least Squares   F-statistic:                              62.61
# Date:                Sun, 02 May 2021   Prob (F-statistic):                    3.58e-24
# Time:                        16:13:43   Log-Likelihood:                         -657.50
# No. Observations:                 375   AIC:                                      1319.
# Df Residuals:                     373   BIC:                                      1327.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# delta_0        0.6827      0.118      5.788      0.000       0.451       0.915
# delta_1        1.4390      0.347      4.148      0.000       0.757       2.121
# ==============================================================================
# Omnibus:                       43.493   Durbin-Watson:                   1.919
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               66.673
# Skew:                          -0.748   Prob(JB):                     3.33e-15
# Kurtosis:                       4.425   Cond. No.                         3.85
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
df = clean_data(get_deltas([f"{x}_is.pkl" for x in delta_sources]))

# %%
blp = pickle.load(open("blp.pkl", "rb"))
df["blp"] = blp
df["score"] = model.predict(df) + df["blp"]
df["delta"] = df["score"] - df["blp"]

# %%
# compute error bars
model_vars = pd.DataFrame()
for col in delta_cols:
    i = col.split("_")[1]
    model_vars[f"model_delta_var_{i}"] = (
        (df[f"delta_var_{i}"] + df[f"delta_{i}"] ** 2)
        * (model.bse[f"delta_{i}"] ** 2 + model.params[f"delta_{i}"] ** 2)
    ) - df[f"delta_{i}"] ** 2 * model.params[f"delta_{i}"] ** 2
model_stds = np.sqrt(model_vars)

delta_corrs = delta_corrs.loc[lambda x: (x.index.isin(delta_cols)), delta_cols]
delta_variance = np.sum(
    (model_stds.values @ delta_corrs.values) * model_stds.values, axis=1
)
intercept_variance = 0
if "Intercept" in model.bse:
    intercept_variance = model.bse["Intercept"] ** 2
df["std"] = np.sqrt(delta_variance + intercept_variance)

zscore = st.norm.ppf(1 - (1 - confidence_interval) / 2)
df["score_lower_bound"] = df["score"] - df["std"] * zscore
df["score_upper_bound"] = df["score"] + df["std"] * zscore

# %%
anime = pd.read_csv("../../AnimeList.csv")
anime = anime[["anime_id", "title", "type"]]
df = df.merge(anime, on="anime_id").set_index("anime_id")

# %%
# reorder the columns
cols = [
    "title",
    "type",
    "score",
    "score_lower_bound",
    "score_upper_bound",
    "delta",
    "std",
] + delta_cols
df = df[cols]  # + [x for x in df.columns if x not in cols]]

# %%
new_recs = df.loc[lambda x: ~x.index.isin(labelled_data.anime_id) & (x["type"] == "TV")]

# %%
df.loc[
    lambda x: (x["delta"] > 0) & ~(x[delta_cols] < 0).all(axis=1)
].sort_values(by="score_lower_bound", ascending=False)[:20]
# Out:
#                                                       title     type  \
# anime_id
# 3297                                   Aria The Origination       TV
# 32           Neon Genesis Evangelion: The End of Evangelion    Movie
# 3784                  Evangelion: 2.0 You Can (Not) Advance    Movie
# 30                                  Neon Genesis Evangelion       TV
# 2001                             Tengen Toppa Gurren Lagann       TV
# 962                                        Aria The Natural       TV
# 11981     Mahou Shoujo Madoka★Magica Movie 3: Hangyaku n...    Movie
# 2759                    Evangelion: 1.0 You Are (Not) Alone    Movie
# 9756                             Mahou Shoujo Madoka★Magica       TV
# 11979     Mahou Shoujo Madoka★Magica Movie 2: Eien no Mo...    Movie
# 2563                                  Aria The OVA: Arietta      OVA
# 820                                    Ginga Eiyuu Densetsu      OVA
# 397                                      Seikai no Senki II       TV
# 29893                                     Aria The Avvenire  Special
# 4772      Aria The Origination: Sono Choppiri Himitsu no...  Special
# 396                                         Seikai no Senki       TV
# 849                              Suzumiya Haruhi no Yuuutsu       TV
# 34376     Yuuki Yuuna wa Yuusha de Aru: Washio Sumi no S...    Movie
# 4565         Tengen Toppa Gurren Lagann Movie 2: Lagann-hen    Movie
# 290                                       Seikai no Monshou       TV
#
#               score  score_lower_bound  score_upper_bound     delta       std  \
# anime_id
# 3297       8.916452           7.517793          10.315111  1.265584  0.542994
# 32         8.880870           7.472135          10.289605  1.556944  0.546906
# 3784       8.551817           7.425428           9.678205  1.006195  0.437292
# 30         8.496619           7.306401           9.686837  1.305599  0.462072
# 2001       7.813388           7.133966           8.492810  0.151802  0.263768
# 962        8.398090           7.123828           9.672351  1.135786  0.494700
# 11981      8.106247           7.109308           9.103186  0.697109  0.387036
# 2759       8.145816           7.040827           9.250806  0.995122  0.428984
# 9756       7.790441           6.975709           8.605173  0.342452  0.316299
# 11979      7.972326           6.974563           8.970090  0.570934  0.387356
# 2563       8.317838           6.962705           9.672970  1.241455  0.526096
# 820        8.022037           6.913035           9.131038  0.150019  0.430541
# 397        8.849591           6.911499          10.787683  1.904588  0.752415
# 29893      8.432175           6.911436           9.952914  1.302528  0.590388
# 4772       8.360152           6.888797           9.831508  1.278533  0.571216
# 396        8.747462           6.859114          10.635810  1.933770  0.733103
# 849        7.637859           6.844061           8.431656  0.582033  0.308172
# 34376     10.163838           6.825871          13.501805  3.070875  1.295880
# 4565       7.774287           6.816341           8.732234  0.240098  0.371898
# 290        8.348150           6.765511           9.930789  1.574261  0.614419
#
#            delta_0   delta_1
# anime_id
# 3297      0.419889  0.680283
# 32       -0.030274  1.096315
# 3784      0.209351  0.599908
# 30        0.146865  0.837614
# 2001     -0.113173  0.159181
# 962       0.684754  0.464429
# 11981    -0.076963  0.520947
# 2759      0.357482  0.521940
# 9756     -0.411264  0.433084
# 11979     0.328184  0.241062
# 2563      0.838548  0.464901
# 820      -0.526598  0.354073
# 397       1.405589  0.656717
# 29893     0.598340  0.621297
# 4772      0.701163  0.555843
# 396       1.378188  0.689996
# 849      -0.012131  0.410222
# 34376     2.629690  0.886472
# 4565      0.313596  0.018077
# 290       1.130285  0.557772

# %%
new_recs.loc[
    lambda x: (x["delta"] > 0) & ~(x[delta_cols] < 0).all(axis=1)
].sort_values(by="score_lower_bound", ascending=False)[:30]
# Out:
#                                           title type     score  \
# anime_id
# 444                  Maria-sama ga Miteru: Haru   TV  7.752174
# 21                                    One Piece   TV  7.531965
# 3604                      Hidamari Sketch x 365   TV  7.427833
# 593                             Mugen no Ryvius   TV  7.726183
# 158                        Maria-sama ga Miteru   TV  7.411296
# 488                            Ichigo Mashimaro   TV  7.066046
# 3750                   Maria-sama ga Miteru 4th   TV  7.641417
# 182                        Tenkuu no Escaflowne   TV  6.994682
# 7062                      Hidamari Sketch x ☆☆☆   TV  7.233572
# 32836              Senki Zesshou Symphogear AXZ   TV  8.606208
# 1852                            Hidamari Sketch   TV  6.916840
# 31771                                  Amanchu!   TV  7.097840
# 427                                Kaleido Star   TV  7.455339
# 11239               Hidamari Sketch x Honeycomb   TV  7.287655
# 34973          Love Live! Sunshine!! 2nd Season   TV  7.829796
# 31706     Fate/kaleid liner Prisma☆Illya 3rei!!   TV  7.656932
# 35240                        Princess Principal   TV  6.894677
# 1088                                    Macross   TV  7.376273
# 165                                   RahXephon   TV  6.758519
# 32681                       Uchuu Patrol Luluco   TV  6.733674
# 2403                       Kodomo no Jikan (TV)   TV  7.403218
# 26                                   Texhnolyze   TV  6.514927
# 2942              Sketchbook: Full Color&#039;s   TV  7.021123
# 21573               Senki Zesshou Symphogear GX   TV  8.276209
# 31500                         High School Fleet   TV  7.462962
# 2986                               Bamboo Blade   TV  6.619425
# 1858             Gakuen Utopia Manabi Straight!   TV  7.103094
# 634                                    Koi Kaze   TV  6.507781
# 26165                          Yuri Kuma Arashi   TV  6.599406
# 35413                      Imouto sae Ireba Ii.   TV  7.314138
#
#           score_lower_bound  score_upper_bound     delta       std   delta_0  \
# anime_id
# 444                6.237421           9.266927  0.892822  0.588064  1.053056
# 21                 6.158456           8.905475  0.104738  0.533230  0.415994
# 3604               6.151248           8.704418  0.557915  0.495602  0.630296
# 593                6.143240           9.309127  1.170213  0.614537  0.888882
# 158                6.040770           8.781821  0.994363  0.532072  1.046183
# 488                5.974164           8.157927  0.314761  0.423895  0.485514
# 3750               5.948315           9.334519  0.629453  0.657304  1.123590
# 182                5.942131           8.047234  0.301330  0.408626  0.307807
# 7062               5.886412           8.580732  0.235103  0.523001  0.390294
# 32836              5.804269          11.408147  2.241017  1.087781  2.302232
# 1852               5.804082           8.029597  0.522510  0.432000  0.516729
# 31771              5.772846           8.422834  0.819394  0.514395  0.660786
# 427                5.771445           9.139233  0.511382  0.653729  0.963790
# 11239              5.740113           8.835198  0.340679  0.600794  0.489917
# 34973              5.720489           9.939103  1.286779  0.818885  1.299187
# 31706              5.719275           9.594589  1.115917  0.752246  1.464261
# 35240              5.697956           8.091398  0.380588  0.464597  0.473778
# 1088               5.680930           9.071617  0.440521  0.658174  0.518613
# 165                5.664078           7.852960  0.282556  0.424889  0.657154
# 32681              5.609080           7.858268  0.354852  0.436595 -0.154924
# 2403               5.597616           9.208820  1.326330  0.700979  1.270633
# 26                 5.576906           7.452948  0.001167  0.364163 -0.426106
# 2942               5.571012           8.471234  0.648425  0.562969  0.765327
# 21573              5.570991          10.981428  1.982103  1.050232  2.416049
# 31500              5.533478           9.392446  1.325591  0.749073  1.581144
# 2986               5.527315           7.711535  0.163210  0.423984  0.249420
# 1858               5.476602           8.729586  0.728820  0.631444  0.928209
# 634                5.468099           7.547464  0.234111  0.403630 -0.083210
# 26165              5.449397           7.749414  0.704198  0.446461 -0.003605
# 35413              5.427421           9.200855  1.132208  0.732470  1.385038
#
#            delta_1
# anime_id
# 444       0.120864
# 21       -0.124566
# 3604      0.088690
# 593       0.391514
# 158       0.194687
# 488      -0.011597
# 3750     -0.095619
# 182       0.063375
# 7062     -0.021780
# 32836     0.465135
# 1852      0.117963
# 31771     0.255933
# 427      -0.101858
# 11239     0.004325
# 34973     0.277867
# 31706     0.080819
# 35240     0.039715
# 1088      0.060094
# 165      -0.115404
# 32681     0.320091
# 2403      0.318898
# 26        0.202959
# 2942      0.087528
# 21573     0.231215
# 31500     0.171076
# 2986     -0.004909
# 1858      0.066123
# 634       0.202164
# 26165     0.491072
# 35413     0.129723
