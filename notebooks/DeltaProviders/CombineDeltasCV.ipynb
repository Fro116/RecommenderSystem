# %%
import functools
import os
import pickle
import random

import numpy as np
import pandas as pd
import scipy.stats as st
import statsmodels.formula.api as smf


@functools.wraps(smf.ols)
def lm(*args, **kwargs):
    return smf.ols(*args, **kwargs).fit()

# %%
recommendee = "Fro116"
confidence_interval = 0.99
delta_sources = ["item", "user"]  # "item", "user"
cross_validate = True  # if true, train linear model on out of sample data

# %%
os.chdir(f"../../data/deltas/{recommendee}")

# %%
def get_deltas(sources):
    deltas = []
    for i, source in enumerate(sources):
        delta = pickle.load(open(source, "rb"))
        delta = delta.rename({x: x + f"_{i}" for x in delta.columns}, axis=1)
        deltas.append(delta)
    return pd.concat(deltas, axis=1)

# %%
def clean_data(df):
    # fill missing data with reasonable defaults
    num_deltas = len([x for x in df.columns if "delta_var" in x])
    for i in range(num_deltas):
        df[f"delta_{i}"] = df[f"delta_{i}"].fillna(0)
        df[f"delta_var_{i}"] = df[f"delta_var_{i}"].fillna(df[f"delta_var_{i}"].max())
    return df

# %%
if cross_validate:
    train_df = get_deltas([f"{x}_oos.pkl" for x in delta_sources])
else:
    train_df = get_deltas([f"{x}_is.pkl" for x in delta_sources])
delta_corrs = train_df[[f"delta_{i}" for i in range(len(delta_sources))]].corr()

# %%
labelled_data = pickle.load(open("recommendee.pkl", "rb"))
labelled_data = clean_data(labelled_data.merge(train_df, on="anime_id"))

# %%
delta_corrs
# Out:
#           delta_0   delta_1
# delta_0  1.000000  0.581461
# delta_1  0.581461  1.000000

# %%
# get model
delta_cols = [f"delta_{i}" for i in range(len(delta_sources))]
formula = "normalized_score ~ 0 +" + " + ".join(delta_cols)
model = lm(formula, labelled_data)
print(model.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:       normalized_score   R-squared (uncentered):                   0.219
# Model:                            OLS   Adj. R-squared (uncentered):              0.215
# Method:                 Least Squares   F-statistic:                              51.97
# Date:                Sat, 15 May 2021   Prob (F-statistic):                    1.27e-20
# Time:                        23:32:09   Log-Likelihood:                         -673.66
# No. Observations:                 373   AIC:                                      1351.
# Df Residuals:                     371   BIC:                                      1359.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# delta_0        1.1200      0.220      5.083      0.000       0.687       1.553
# delta_1        1.2978      0.378      3.432      0.001       0.554       2.041
# ==============================================================================
# Omnibus:                       28.010   Durbin-Watson:                   1.945
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               33.979
# Skew:                          -0.623   Prob(JB):                     4.18e-08
# Kurtosis:                       3.797   Cond. No.                         2.64
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
df = clean_data(get_deltas([f"{x}_is.pkl" for x in delta_sources]))

# %%
blp = pickle.load(open("blp.pkl", "rb"))
df["blp"] = blp
df["score"] = model.predict(df) + df["blp"]
df["delta"] = df["score"] - df["blp"]

# %%
# compute error bars
model_vars = pd.DataFrame()
for col in delta_cols:
    i = col.split("_")[1]
    model_vars[f"model_delta_var_{i}"] = (
        (df[f"delta_var_{i}"] + df[f"delta_{i}"] ** 2)
        * (model.bse[f"delta_{i}"] ** 2 + model.params[f"delta_{i}"] ** 2)
    ) - df[f"delta_{i}"] ** 2 * model.params[f"delta_{i}"] ** 2
model_stds = np.sqrt(model_vars)

delta_corrs = delta_corrs.loc[lambda x: (x.index.isin(delta_cols)), delta_cols]
delta_variance = np.sum(
    (model_stds.values @ delta_corrs.values) * model_stds.values, axis=1
)
intercept_variance = 0
if "Intercept" in model.bse:
    intercept_variance = model.bse["Intercept"] ** 2
df["std"] = np.sqrt(delta_variance + intercept_variance)

zscore = st.norm.ppf(1 - (1 - confidence_interval) / 2)
df["score_lower_bound"] = df["score"] - df["std"] * zscore
df["score_upper_bound"] = df["score"] + df["std"] * zscore
# Out:
# <ipython-input-12-dc42af8cba78>:13: RuntimeWarning: invalid value encountered in matmul
#   (model_stds.values @ delta_corrs.values) * model_stds.values, axis=1

# %%
anime = pd.read_csv("../../AnimeList.csv")
anime = anime[["anime_id", "title", "type"]]
df = df.merge(anime, on="anime_id").set_index("anime_id")

# %%
# reorder the columns
cols = [
    "title",
    "type",
    "score",
    "score_lower_bound",
    "score_upper_bound",
    "delta",
    "std",
] + delta_cols
df = df[cols + [x for x in df.columns if x not in cols]]

# %%
new_recs = df.loc[lambda x: ~x.index.isin(labelled_data.anime_id) & (x["type"] == "TV")]

# %%
df.loc[lambda x: (x["delta"] > 0)].sort_values(by="score_lower_bound", ascending=False)[
    :20
]
# Out:
#                                                       title     type  \
# anime_id
# 3297                                   Aria The Origination       TV
# 32           Neon Genesis Evangelion: The End of Evangelion    Movie
# 3784                  Evangelion: 2.0 You Can (Not) Advance    Movie
# 820                                    Ginga Eiyuu Densetsu      OVA
# 11981     Mahou Shoujo Madoka★Magica Movie 3: Hangyaku n...    Movie
# 30                                  Neon Genesis Evangelion       TV
# 9756                             Mahou Shoujo Madoka★Magica       TV
# 11979     Mahou Shoujo Madoka★Magica Movie 2: Eien no Mo...    Movie
# 962                                        Aria The Natural       TV
# 9617                                            K-On! Movie    Movie
# 2759                    Evangelion: 1.0 You Are (Not) Alone    Movie
# 2563                                  Aria The OVA: Arietta      OVA
# 849                              Suzumiya Haruhi no Yuuutsu       TV
# 11977     Mahou Shoujo Madoka★Magica Movie 1: Hajimari n...    Movie
# 29893                                     Aria The Avvenire  Special
# 397                                      Seikai no Senki II       TV
# 7791                                                 K-On!!       TV
# 34376     Yuuki Yuuna wa Yuusha de Aru: Washio Sumi no S...    Movie
# 4772      Aria The Origination: Sono Choppiri Himitsu no...  Special
# 18617                                  Girls & Panzer Movie    Movie
#
#              score  score_lower_bound  score_upper_bound     delta       std  \
# anime_id
# 3297      8.577507           7.259643           9.895370  1.012609  0.511627
# 32        8.610783           7.124759          10.096808  1.372855  0.576911
# 3784      8.145666           7.104892           9.186441  0.686015  0.404054
# 820       8.260103           7.066259           9.453947  0.473956  0.463479
# 11981     7.912137           6.958112           8.866162  0.588947  0.370376
# 30        8.187171           6.955523           9.418819  1.082123  0.478156
# 9756      7.701197           6.918146           8.484247  0.339171  0.303999
# 11979     7.701688           6.907411           8.495965  0.386266  0.308358
# 962       8.035920           6.902361           9.169480  0.859586  0.440076
# 444       0.084805     0.082031     0.040952  6.773382
# 19111    -0.090461     0.091230     0.011599  6.838430
# 593       0.365377     0.059581     0.040354  6.470001
# 33089     0.464653     0.073477     0.033021  6.325981
# 14131     0.064104     0.042567     0.011149  6.453799
# 34973     0.220806     0.113491     0.046740  6.457047
# 158       0.177655     0.070471     0.031900  6.330963
# 1852      0.173589     0.034359     0.016621  6.308360
# 23269     0.097456     0.065329     0.020346  6.486389
# 427      -0.094699     0.104251     0.045804  6.857987
# 35240     0.035143     0.046819     0.015701  6.428120
# 85        0.144790     0.080153     0.044852  6.825587
# 147       0.124684     0.043462     0.008324  6.276708
# 31771     0.275771     0.034315     0.020682  6.192476
# 122       0.012042     0.123531     0.036636  6.850261
# 3750     -0.124785     0.092832     0.050255  6.925994
# 26        0.222104     0.037665     0.011384  6.427790
# 21273     0.053971     0.063994     0.011620  6.357192
# 32526     0.077840     0.093024     0.020120  6.284532
# 1065      0.011101     0.096628     0.078891  6.925062
# 35241     0.025248     0.072313     0.036283  6.393960
# 2986     -0.050306     0.052305     0.018056  6.370245
# 31706    -0.015857     0.069980     0.024533  6.455045

# %%
new_recs.loc[lambda x: (x["delta_0"] < 0) & (x["delta_1"] > 0)].sort_values(
    by="score_lower_bound", ascending=False
)[:20]
# Out:
#                                               title type     score  \
# anime_id
# 182                            Tenkuu no Escaflowne   TV  6.594651
# 85                          Mobile Suit Zeta Gundam   TV  7.005354
# 147                             Kimi ga Nozomu Eien   TV  6.421694
# 31771                                      Amanchu!   TV  6.550243
# 26                                       Texhnolyze   TV  6.429416
# 1453                                  Maison Ikkoku   TV  6.988106
# 80                               Mobile Suit Gundam   TV  6.722951
# 2402                                  Ashita no Joe   TV  7.220074
# 2921                                Ashita no Joe 2   TV  7.493085
# 26165                              Yuri Kuma Arashi   TV  6.248925
# 32681                           Uchuu Patrol Luluco   TV  6.261824
# 1454                                     Kemonozume   TV  6.199711
# 32607                             Gi(a)rlish Number   TV  6.028062
# 369       Boogiepop wa Warawanai: Boogiepop Phantom   TV  6.047683
# 567                                       The Big O   TV  6.194363
# 8726                   Soredemo Machi wa Mawatteiru   TV  5.896424
# 469                                           Karin   TV  6.152819
# 874                                  Digimon Tamers   TV  6.209055
# 878                                        Zegapain   TV  6.429905
# 16051                                 Ro-Kyu-Bu! SS   TV  6.488472
#
#           score_lower_bound  score_upper_bound     delta       std   delta_0  \
# anime_id
# 182                5.623813           7.565488 -0.012732  0.376903 -0.058731
# 85                 5.597014           8.413694  0.179767  0.546752 -0.007264
# 147                5.564985           7.278404  0.144987  0.332595 -0.015020
# 31771              5.560566           7.539920  0.357767  0.384217 -0.000105
# 26                 5.520616           7.338216  0.001626  0.352818 -0.255894
# 1453               5.470771           8.505441 -0.025850  0.589067 -0.063060
# 80                 5.410736           8.035166  0.055934  0.509434 -0.121945
# 2402               5.299414           9.140735  0.320260  0.745647 -0.172064
# 2921               5.230003           9.756167  0.032268  0.878584 -0.299554
# 26165              5.184642           7.313207  0.439687  0.413181 -0.056350
# 32681              5.141281           7.382368 -0.031028  0.435022 -0.354357
# 1454               5.060311           7.339111 -0.084429  0.442343 -0.276624
# 32607              5.013086           7.043038  0.186690  0.394039 -0.074711
# 369                4.976376           7.118991  0.026185  0.415908 -0.131975
# 567                4.922410           7.466316 -0.120017  0.493803 -0.186919
# 8726               4.914049           6.878799 -0.395393  0.381382 -0.411559
# 469                4.860913           7.444725 -0.104819  0.501550 -0.165926
# 874                4.844771           7.573339 -0.100168  0.529648 -0.118131
# 878                4.797804           8.062006  0.146572  0.633622 -0.150485
# 16051              4.790586           8.186357  0.323268  0.659161 -0.103044
#
#            delta_1  delta_var_0  delta_var_1       blp
# anime_id
# 182       0.040878     0.046723     0.016660  6.607382
# 85        0.144790     0.080153     0.044852  6.825587
# 147       0.124684     0.043462     0.008324  6.276708
# 31771     0.275771     0.034315     0.020682  6.192476
# 26        0.222104     0.037665     0.011384  6.427790
# 1453      0.034506     0.108358     0.044287  7.013956
# 80        0.148346     0.081311     0.031058  6.667017
# 2402      0.395281     0.103870     0.107229  6.899814
# 2921      0.283397     0.094440     0.205213  7.460817
# 26165     0.387438     0.041349     0.017762  5.809238
# 32681     0.281922     0.061880     0.013925  6.292853
# 1454      0.173685     0.052422     0.026253  6.284140
# 32607     0.208335     0.040794     0.021171  5.841372
# 369       0.134079     0.042304     0.027830  6.021499
# 567       0.068842     0.072958     0.031985  6.314380
# 8726      0.050525     0.044326     0.015555  6.291817
# 469       0.062434     0.105601     0.017972  6.257638
# 874       0.024768     0.127296     0.016782  6.309223
# 878       0.242820     0.120971     0.048927  6.283333
# 16051     0.338030     0.144390     0.041595  6.165203

# %%
new_recs.loc[lambda x: (x["delta_0"] > 0) & (x["delta_1"] < 0)].sort_values(
    by="score_lower_bound", ascending=False
)[:20]
# Out:
#                                               title type     score  \
# anime_id
# 34914                                    New Game!!   TV  6.919471
# 30279                            Yuru Yuri San☆Hai!   TV  6.848207
# 19111     Love Live! School Idol Project 2nd Season   TV  6.944944
# 427                                    Kaleido Star   TV  7.186301
# 30727                Saenai Heroine no Sodatekata ♭   TV  6.535085
# 3750                       Maria-sama ga Miteru 4th   TV  7.044134
# 2986                                   Bamboo Blade   TV  6.496483
# 31706         Fate/kaleid liner Prisma☆Illya 3rei!!   TV  6.651480
# 10278                                The iDOLM@STER   TV  6.360286
# 1222                                  Bokura ga Ita   TV  6.421844
# 20509          Fate/kaleid liner Prisma☆Illya 2wei!   TV  6.409666
# 5671                                           Saki   TV  6.362592
# 35860                   Karakai Jouzu no Takagi-san   TV  6.454115
# 33988                        Demi-chan wa Kataritai   TV  6.269270
# 16732                                 Kiniro Mosaic   TV  6.310099
# 31952           Kono Bijutsubu ni wa Mondai ga Aru!   TV  6.299717
# 2035        Eikoku Koi Monogatari Emma: Molders-hen   TV  6.759404
# 1974                          Glass no Kamen (2005)   TV  7.074243
# 15731                     Tamayura: More Aggressive   TV  6.744973
# 21681                                    Hanayamata   TV  6.282310
#
#           score_lower_bound  score_upper_bound     delta       std   delta_0  \
# anime_id
# 34914              5.939470           7.899473  0.153111  0.380460  0.163180
# 30279              5.835974           7.860439 -0.024268  0.392973  0.055982
# 19111              5.782591           8.107297  0.106514  0.451254  0.199912
# 427                5.646797           8.725806  0.328315  0.597673  0.402852
# 30727              5.608058           7.462112 -0.138812  0.359894  0.003351
# 3750               5.534165           8.554103  0.118140  0.586207  0.250062
# 2986               5.469533           7.523434  0.126238  0.398687  0.170997
# 31706              5.462710           7.840249  0.196434  0.461509  0.193754
# 10278              5.438937           7.281634 -0.139352  0.357690  0.015037
# 1222               5.400334           7.443354  0.057599  0.396575  0.057148
# 20509              5.382365           7.436968  0.135342  0.398824  0.154928
# 5671               5.375028           7.350156 -0.027538  0.383397  0.061135
# 35860              5.324434           7.583795 -0.096777  0.438570  0.073729
# 33988              5.308287           7.230253 -0.314181  0.373077  0.028720
# 16732              5.301624           7.318575  0.085693  0.391515  0.093062
# 31952              5.277114           7.322320  0.071026  0.396999  0.112615
# 2035               5.223240           8.295568 -0.200151  0.596376  0.051838
# 1974               5.211240           8.937246  0.043291  0.723263  0.101163
# 15731              5.204192           8.285755  0.344755  0.598169  0.339336
# 21681              5.195375           7.369245  0.101737  0.421975  0.162725
#
#            delta_1  delta_var_0  delta_var_1       blp
# anime_id
# 34914    -0.022853     0.046156     0.017397  6.766361
# 30279    -0.067015     0.055767     0.015284  6.872475
# 19111    -0.090461     0.091230     0.011599  6.838430
# 427      -0.094699     0.104251     0.045804  6.857987
# 30727    -0.109855     0.046328     0.012445  6.673897
# 3750     -0.124785     0.092832     0.050255  6.925994
# 2986     -0.050306     0.052305     0.018056  6.370245
# 31706    -0.015857     0.069980     0.024533  6.455045
# 10278    -0.120357     0.039500     0.015522  6.499638
# 1222     -0.004939     0.060797     0.013973  6.364245
# 20509    -0.029423     0.062262     0.013353  6.274325
# 5671     -0.073983     0.053608     0.014176  6.390129
# 35860    -0.138205     0.072013     0.016687  6.550892
# 33988    -0.266882     0.049682     0.008851  6.583451
# 16732    -0.014287     0.064102     0.011353  6.224407
# 31952    -0.042463     0.063660     0.012461  6.228691
# 2035     -0.198967     0.095456     0.052091  6.959555
# 1974     -0.053951     0.153183     0.072656  7.030952
# 15731    -0.027213     0.106754     0.046194  6.400218
# 21681    -0.062047     0.067538     0.015732  6.180574

# %%
new_recs.loc[lambda x: (x["delta_0"] > 0) & (x["delta_1"] > 0)].sort_values(
    by="score_lower_bound", ascending=False
)[:20]
# Out:
#                                      title type     score  score_lower_bound  \
# anime_id
# 7062                 Hidamari Sketch x ☆☆☆   TV  7.153846           6.122063
# 3604                 Hidamari Sketch x 365   TV  7.075402           6.073713
# 29787         Gochuumon wa Usagi desu ka??   TV  7.077194           6.005286
# 11239          Hidamari Sketch x Honeycomb   TV  7.121739           5.989686
# 488                       Ichigo Mashimaro   TV  6.804244           5.855621
