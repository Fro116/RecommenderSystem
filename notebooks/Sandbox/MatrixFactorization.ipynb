# %%
import os
import pickle

import implicit
import numpy as np
import pandas as pd
import scipy.sparse
from tqdm import tqdm

# %%
df = pickle.load(open("../../data/cleaned_data/user_anime_lists.pkl", "rb"))

# %% [markdown]
# ## TODO remove this

# %%
extra = pickle.load(
    open("../../../anime_recommender/data/user_profiles/ExtraUserAnimeLists.pkl", "rb")
)
df = pd.concat(
    [
        df.loc[lambda x: ~x["username"].isin(extra.username)],
        extra[["username", "anime_id", "my_score"]],
    ],
    ignore_index=True,
)

# %% [markdown]
# # Normalization

# %%
average_rating = df["my_score"].mean()
user_bias = (
    pd.DataFrame(df.groupby("username")["my_score"].mean()).rename(
        {"my_score": "user_bias"}, axis=1
    )
    - average_rating
)
anime_bias = (
    pd.DataFrame(df.groupby("anime_id")["my_score"].mean()).rename(
        {"my_score": "anime_bias"}, axis=1
    )
    - average_rating
)

# %%
df = df.merge(anime_bias, on=["anime_id"]).merge(user_bias, on=["username"])
df["normalized_score"] = (
    df["my_score"] - df["anime_bias"] - df["user_bias"] - average_rating
)
df = df.dropna()

# %% [markdown]
# ## Create a sparse matrix

# %%
user_ids = df[["username"]].drop_duplicates().reset_index(drop=True)
user_ids = user_ids.reset_index().rename({"index": "user_id"}, axis=1)

# %%
df = df.merge(user_ids, on="username")

# %%
# user-item matrix
R = scipy.sparse.coo_matrix((df["normalized_score"], (df["user_id"], df["anime_id"])))

# %%
for i, j, v in zip(R.row, R.col, R.data):
    print(i, j, v)
    break
# Out:
# 0 21 0.6054736476506148

# %% [markdown]
# ## Alternating least squares

# %%
# number of latent factors
K = 100

# user factors
X = np.random.default_rng().standard_normal((R.shape[0], K))

# item factors
Y = np.random.default_rng().standard_normal((K, R.shape[1]))

# %%
X[u, :]
# Out:
# array([ 0.84212542,  0.05647956,  1.38422928, -1.36568152,  1.23047597,
#         0.39157219, -1.32036218,  0.74737695,  1.45640601, -0.59180446,
#         0.04172253, -0.33977628,  0.63848984, -1.95739427,  0.38294226,
#        -0.35605178,  0.33851752, -0.50882693,  1.36308425,  0.85092368,
#         1.3924999 , -0.96214204, -0.57909811, -1.34670968, -1.26801485,
#         1.49039446,  2.30033795,  0.83923011, -0.50188251, -1.10540208,
#         0.3411895 , -1.78600506, -0.69228697, -0.8132054 , -0.2222082 ,
#        -0.54112389, -0.83781031, -1.13588837, -0.79517271,  0.12945712,
#         1.2039863 , -0.5435222 ,  0.85138593, -1.22453001,  1.45314017,
#         1.63273581,  2.09341116, -0.41821475, -0.12447563,  2.31109379,
#        -0.59378683,  0.53123804, -0.54914307,  0.3932507 ,  0.62264041,
#         0.81384629, -0.04167501, -0.98871111, -1.21091292,  2.49631177,
#        -1.71541655, -0.2511828 ,  0.45922761, -0.9633358 , -1.66269875,
#        -2.23966565,  0.77250337,  0.06432058, -0.89757292,  0.66161832,
#        -0.3840732 , -0.43105089,  0.40373407,  0.04275403, -1.87542315,
#         0.21606597, -1.7383012 , -0.36051853,  0.05561519,  1.21555723,
#        -0.37302871, -0.5873461 , -1.11284089, -0.25689159,  1.61367824,
#        -1.19216103,  0.89007635,  0.15139463,  2.25612696,  0.02586047,
#         1.16146868, -0.77492653, -0.65396342,  1.28872042, -0.34300401,
#        -0.12280297,  1.34300824,  0.52123493,  0.38190023, -0.29690517])

# %%
for u, i, r in tqdm(zip(R.row, R.col, R.data)):
    print((X[u, :] @ Y[:, i]) ** 2)
    break
# Out:
# 0it [00:00, ?it/s]
# 194.04008707580823

# %%
def training_loss(X, Y, R, λ):
    sse = 0
    N = 0
    for u, i, r in tqdm(zip(R.row, R.col, R.data)):
        sse += (r - X[u, :] @ Y[:, i]) ** 2
        N += 1
    return sse + λ * np.sum(X ** 2) + λ * np.sum(Y ** 2)

# %%
training_loss(X, Y, R, 0.1)
# Out:
# 46358416it [02:14, 343953.73it/s]
# 4722489251.045748

# %%
user_item_mat[:, 0].asformat("coo")
# Out:
# <271680x1 sparse matrix of type '<class 'numpy.float64'>'
# 	with 0 stored elements in COOrdinate format>

# %%
X.T @ user_item_mat[:, 1]
# Out:
# array([[ -66.00332253],
#        [-483.78396434],
#        [-596.32905136],
#        [ 673.88067637],
#        [ 281.20442432],
#        [-366.30276219],
#        [ 653.57415375],
#        [-163.59993002],
#        [-906.01998437],
#        [-589.28197515]])

# %%
user_item_mat[:, 1].shape
# Out:
# (271680, 1)

# %%
X[:, 0].shape
# Out:
# (271680,)

# %%
X.T[0, :] + user_item_mat[:, 1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-58-24aa5df632fc> in <module>
# ----> 1 X.T[0,:] + user_item_mat[:, 1]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/scipy/sparse/base.py in __radd__(self, other)
#     421
#     422     def __radd__(self,other):  # other + self
# --> 423         return self.__add__(other)
#     424
#     425     def __sub__(self, other):  # self - other
#
# ~/opt/anaconda3/lib/python3.8/site-packages/scipy/sparse/base.py in __add__(self, other)
#     415             return self._add_sparse(other)
#     416         elif isdense(other):
# --> 417             other = np.broadcast_to(other, self.shape)
#     418             return self._add_dense(other)
#     419         else:
#
# <__array_function__ internals> in broadcast_to(*args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/lib/stride_tricks.py in broadcast_to(array, shape, subok)
#     409            [1, 2, 3]])
#     410     """
# --> 411     return _broadcast_to(array, shape, subok=subok, readonly=True)
#     412
#     413
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/lib/stride_tricks.py in _broadcast_to(array, shape, subok, readonly)
#     346                          'negative')
#     347     extras = []
# --> 348     it = np.nditer(
#     349         (array,), flags=['multi_index', 'refs_ok', 'zerosize_ok'] + extras,
#     350         op_flags=['readonly'], itershape=shape, order='C')
#
# ValueError: operands could not be broadcast together with remapped shapes [original->remapped]: (271680,)  and requested shape (271680,1)

# %%
user_item_mat[:, 1].nonzero()
# Out:
# (array([     1,      2,      4, ..., 236466, 236467, 236468], dtype=int32),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=int32))

# %%
X.T
# Out:
# array([[ 0.06562139,  1.42791229,  0.35396757, ..., -0.84945667,
#          0.28283718,  0.2770499 ],
#        [ 0.23053862,  0.22440642, -0.33240749, ...,  0.05164753,
#          1.26772036, -0.66471765],
#        [ 1.46876118,  0.37393615,  0.68481032, ...,  0.9879699 ,
#         -0.10498704, -0.19720801],
#        ...,
#        [ 0.72083975,  0.44724505, -0.29310862, ...,  0.79588235,
#          1.93882171,  0.19430441],
#        [-0.98483782, -1.2906035 , -0.1195464 , ..., -1.32094051,
#         -1.48430006,  0.1173306 ],
#        [-0.2262312 , -0.72189462,  0.86276658, ..., -0.64379972,
#         -1.34893883, -0.64031335]])

# %%
X.T @ X - user_item_mat[:, 0]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-71b8362713e4> in <module>
# ----> 1 X.T @ X - user_item_mat[:, 0]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/scipy/sparse/base.py in __rsub__(self, other)
#     446                                       'nonzero scalar is not supported')
#     447         elif isdense(other):
# --> 448             other = np.broadcast_to(other, self.shape)
#     449             return self._rsub_dense(other)
#     450         else:
#
# <__array_function__ internals> in broadcast_to(*args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/lib/stride_tricks.py in broadcast_to(array, shape, subok)
#     409            [1, 2, 3]])
#     410     """
# --> 411     return _broadcast_to(array, shape, subok=subok, readonly=True)
#     412
#     413
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/lib/stride_tricks.py in _broadcast_to(array, shape, subok, readonly)
#     346                          'negative')
#     347     extras = []
# --> 348     it = np.nditer(
#     349         (array,), flags=['multi_index', 'refs_ok', 'zerosize_ok'] + extras,
#     350         op_flags=['readonly'], itershape=shape, order='C')
#
# ValueError: operands could not be broadcast together with remapped shapes [original->remapped]: (10,10)  and requested shape (271680,1)

# %%
np.random.normal()

# %%
df
# Out:
#                username  anime_id  my_score  anime_bias  user_bias  \
# 0              karthiga        21         9    0.960564  -0.059898
# 1              karthiga        59         7    0.040203  -0.059898
# 2              karthiga        74         7    0.316282  -0.059898
# 3              karthiga       120         7    0.309858  -0.059898
# 4              karthiga       178         7   -0.227339  -0.059898
# ...                 ...       ...       ...         ...        ...
# 46358411   temptemptemp     10040         6   -1.636717  -1.493860
# 46358412  cinnamoroller     12963        10   -0.798860   2.506140
# 46358413      inactiveX      5143         7   -0.652951  -0.493860
# 46358414           omgm      5581         5   -1.857497  -2.493860
# 46358415   CategoryKing     33669         1   -1.592345  -6.493860
#
#           normalized_score  user_id
# 0                 0.605474        0
# 1                -0.474165        0
# 2                -0.750245        0
# 3                -0.743821        0
# 4                -0.206624        0
# ...                    ...      ...
# 46358411          1.636717   271675
# 46358412          0.798860   271676
# 46358413          0.652951   271677
# 46358414          1.857497   271678
# 46358415          1.592345   271679
#
# [46358416 rows x 7 columns]

# %%
os.environ["MKL_NUM_THREADS"] = "1"

# %%
model = implicit.als.AlternatingLeastSquares(factors=50)

# %%
model.fit(sparse_mat)
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]

# %%
recs = pd.DataFrame.from_records(
    model.recommend(19671, sparse_mat, 1000), columns=["anime_id", "score"]
)

# %%
seen_shows = df.loc[lambda x: x["username"] == "Fro116"]

# %%
recs.merge(seen_shows, on=["anime_id"])[["score", "my_score"]].corr()
# Out:
#              score  my_score
# score     1.000000  0.142057
# my_score  0.142057  1.000000

# %%
anime = pd.read_csv("../../data/cleaned_data/anime.csv")

# %%
recs.loc[lambda x: ~x.anime_id.isin(seen_shows.anime_id)].merge(
    anime, on="anime_id"
).loc[lambda x: x["type"] == "TV"][:30]
# Out:
#     anime_id     score  Unnamed: 0                             title  \
# 2      16498  1.125039        8123                Shingeki no Kyojin
# 5      22319  1.000904        1235                       Tokyo Ghoul
# 10     30276  0.909803        8863                     One Punch Man
# 11     28223  0.853507       12967                      Death Parade
# 12      7054  0.832874          11             Kaichou wa Maid-sama!
# 13     22535  0.829360        9232        Kiseijuu: Sei no Kakuritsu
# 15     27899  0.817018       12935                    Tokyo Ghoul √A
# 16     14227  0.809003          13            Tonari no Kaibutsu-kun
# 17      5114  0.793178        2555  Fullmetal Alchemist: Brotherhood
# 18      6045  0.785958          16                    Kimi ni Todoke
# 19     18153  0.774362        1471                 Kyoukai no Kanata
# 20     22199  0.766068        5463                    Akame ga Kill!
# 21      6746  0.761906        9555                        Durarara!!
# 23      9919  0.734740        5437                    Ao no Exorcist
# 24     22789  0.731038        3116                         Barakamon
# 25     13601  0.721468        3226                       Psycho-Pass
# 26     21995  0.716090        7446                      Ao Haru Ride
# 27      4898  0.712657       13711                      Kuroshitsuji
# 28      6702  0.702549         191                        Fairy Tail
# 31     18897  0.695744        6806                           Nisekoi
# 32      8074  0.692423        4825            Highschool of the Dead
# 33       120  0.686635          32                     Fruits Basket
# 34     28297  0.677928        6485                  Ore Monogatari!!
# 35     30503  0.673027        6754                  Noragami Aragoto
# 37     24833  0.657713         932                Ansatsu Kyoushitsu
# 38        20  0.656313        4504                            Naruto
# 39     14289  0.652766        1023                 Sukitte Ii na yo.
# 41     28999  0.646640        3558                         Charlotte
# 42      3588  0.631614        8453                        Soul Eater
# 43     23755  0.628890         915                 Nanatsu no Taizai
#
#                                                genres type  \
# 2   Action, Military, Mystery, Super Power, Drama,...   TV
# 5   Action, Mystery, Horror, Psychological, Supern...   TV
# 10  Action, Sci-Fi, Comedy, Parody, Super Power, S...   TV
# 11      Game, Mystery, Psychological, Drama, Thriller   TV
# 12                    Comedy, Romance, School, Shoujo   TV
# 13  Action, Sci-Fi, Horror, Psychological, Drama, ...   TV
# 15  Action, Mystery, Horror, Psychological, Supern...   TV
# 16     Slice of Life, Comedy, Romance, School, Shoujo   TV
# 17  Action, Military, Adventure, Comedy, Drama, Ma...   TV
# 18      Slice of Life, Drama, Romance, School, Shoujo   TV
# 19               Slice of Life, Supernatural, Fantasy   TV
# 20         Action, Adventure, Drama, Fantasy, Shounen   TV
# 21                      Action, Mystery, Supernatural   TV
# 23     Action, Demons, Fantasy, Shounen, Supernatural   TV
# 24                              Comedy, Slice of Life   TV
# 25              Action, Police, Psychological, Sci-Fi   TV
# 26  Comedy, Drama, Romance, School, Shoujo, Slice ...   TV
# 27  Action, Comedy, Demons, Fantasy, Historical, S...   TV
# 28  Action, Adventure, Comedy, Magic, Fantasy, Sho...   TV
# 31            Harem, Comedy, Romance, School, Shounen   TV
# 32       Action, Horror, Supernatural, Ecchi, Shounen   TV
# 33  Slice of Life, Comedy, Drama, Romance, Fantasy...   TV
# 34                            Comedy, Romance, Shoujo   TV
# 35   Action, Adventure, Comedy, Supernatural, Shounen   TV
# 37                    Action, Comedy, School, Shounen   TV
# 38  Action, Adventure, Comedy, Super Power, Martia...   TV
# 39                     Drama, Romance, School, Shoujo   TV
# 41                         Drama, School, Super Power   TV
# 42     Action, Fantasy, Comedy, Supernatural, Shounen   TV
# 43  Action, Adventure, Supernatural, Magic, Ecchi,...   TV
#
#                                         related_anime
# 2   [{'anime_id': 18397, 'relation': 'Side story'}...
# 5   [{'anime_id': 27899, 'relation': 'Sequel'}, {'...
# 10  [{'anime_id': 31704, 'relation': 'Side story'}...
# 11  [{'anime_id': 14353, 'relation': 'Alternative ...
# 12  [{'anime_id': 9366, 'relation': 'Side story'},...
# 13                                                 []
# 15  [{'anime_id': 22319, 'relation': 'Prequel'}, {...
# 16  [{'anime_id': 16866, 'relation': 'Alternative ...
# 17  [{'anime_id': 121, 'relation': 'Alternative ve...
# 18  [{'anime_id': 9656, 'relation': 'Sequel'}, {'a...
# 19  [{'anime_id': 17813, 'relation': 'Other'}, {'a...
# 20  [{'anime_id': 25241, 'relation': 'Other'}, {'a...
# 21  [{'anime_id': 8408, 'relation': 'Side story'},...
# 23  [{'anime_id': 10647, 'relation': 'Side story'}...
# 24  [{'anime_id': 25045, 'relation': 'Other'}, {'a...
# 25  [{'anime_id': 17901, 'relation': 'Other'}, {'a...
# 26    [{'anime_id': 24151, 'relation': 'Side story'}]
# 27  [{'anime_id': 6163, 'relation': 'Summary'}, {'...
# 28  [{'anime_id': 246, 'relation': 'Character'}, {...
# 31  [{'anime_id': 27787, 'relation': 'Sequel'}, {'...
# 32     [{'anime_id': 9515, 'relation': 'Side story'}]
# 33                                                 []
# 34                                                 []
# 35  [{'anime_id': 20507, 'relation': 'Prequel'}, {...
# 37  [{'anime_id': 19759, 'relation': 'Alternative ...
# 38  [{'anime_id': 442, 'relation': 'Side story'}, ...
# 39  [{'anime_id': 16868, 'relation': 'Sequel'}, {'...
# 41    [{'anime_id': 31553, 'relation': 'Side story'}]
# 42  [{'anime_id': 21195, 'relation': 'Summary'}, {...
# 43  [{'anime_id': 30347, 'relation': 'Side story'}...

# %%
recs.loc[lambda x: ~x.anime_id.isin(seen_shows.anime_id)].merge(
    anime, on="anime_id"
).loc[lambda x: x["type"] == "TV"][:30]
# Out:
#     anime_id     score  Unnamed: 0                                  title  \
# 0      16498  0.897526        8123                     Shingeki no Kyojin
# 1       5114  0.843040        2555       Fullmetal Alchemist: Brotherhood
# 2       6746  0.833527        9555                             Durarara!!
# 5       4898  0.790061       13711                           Kuroshitsuji
# 6          1  0.762213        9132                           Cowboy Bebop
# 7       7054  0.761894          11                  Kaichou wa Maid-sama!
# 8      13601  0.759568        3226                            Psycho-Pass
# 9         20  0.758924        4504                                 Naruto
# 10      9919  0.751778        5437                         Ao no Exorcist
# 11      3588  0.750829        8453                             Soul Eater
# 12     30276  0.748766        8863                          One Punch Man
# 13     22319  0.747155        1235                            Tokyo Ghoul
# 14      6045  0.745603          16                         Kimi ni Todoke
# 15      2251  0.734591        7238                               Baccano!
# 16     14227  0.724538          13                 Tonari no Kaibutsu-kun
# 17       205  0.698655        6463                       Samurai Champloo
# 18     28223  0.695769       12967                           Death Parade
# 19       269  0.678616          14                                 Bleach
# 20      8074  0.676341        4825                 Highschool of the Dead
# 22      3457  0.674743         848                         Vampire Knight
# 23      6880  0.673509       12228                     Deadman Wonderland
# 25      2025  0.664717         306  Darker than Black: Kuro no Keiyakusha
# 26     22535  0.660454        9232             Kiseijuu: Sei no Kakuritsu
# 27     14289  0.656725        1023                      Sukitte Ii na yo.
# 28      6702  0.653898         191                             Fairy Tail
# 29     11771  0.651365        3630                       Kuroko no Basket
# 30      6707  0.649851         401                        Kuroshitsuji II
# 32       120  0.645093          32                          Fruits Basket
# 34     18153  0.630307        1471                      Kyoukai no Kanata
# 35       877  0.629431         660                                   Nana
#
#                                                genres type  \
# 0   Action, Military, Mystery, Super Power, Drama,...   TV
# 1   Action, Military, Adventure, Comedy, Drama, Ma...   TV
# 2                       Action, Mystery, Supernatural   TV
# 5   Action, Comedy, Demons, Fantasy, Historical, S...   TV
# 6     Action, Adventure, Comedy, Drama, Sci-Fi, Space   TV
# 7                     Comedy, Romance, School, Shoujo   TV
# 8               Action, Police, Psychological, Sci-Fi   TV
# 9   Action, Adventure, Comedy, Super Power, Martia...   TV
# 10     Action, Demons, Fantasy, Shounen, Supernatural   TV
# 11     Action, Fantasy, Comedy, Supernatural, Shounen   TV
# 12  Action, Sci-Fi, Comedy, Parody, Super Power, S...   TV
# 13  Action, Mystery, Horror, Psychological, Supern...   TV
# 14      Slice of Life, Drama, Romance, School, Shoujo   TV
# 15  Action, Mystery, Comedy, Historical, Supernatural   TV
# 16     Slice of Life, Comedy, Romance, School, Shoujo   TV
# 17  Action, Adventure, Comedy, Historical, Samurai...   TV
# 18      Game, Mystery, Psychological, Drama, Thriller   TV
# 19  Action, Adventure, Comedy, Super Power, Supern...   TV
# 20       Action, Horror, Supernatural, Ecchi, Shounen   TV
# 22  Drama, Mystery, Romance, Shoujo, Supernatural,...   TV
# 23                    Action, Sci-Fi, Horror, Shounen   TV
# 25               Action, Sci-Fi, Mystery, Super Power   TV
# 26  Action, Sci-Fi, Horror, Psychological, Drama, ...   TV
# 27                     Drama, Romance, School, Shoujo   TV
# 28  Action, Adventure, Comedy, Magic, Fantasy, Sho...   TV
# 29                    Comedy, School, Shounen, Sports   TV
# 30  Action, Comedy, Demons, Supernatural, Fantasy,...   TV
# 32  Slice of Life, Comedy, Drama, Romance, Fantasy...   TV
# 34               Slice of Life, Supernatural, Fantasy   TV
# 35  Music, Slice of Life, Comedy, Drama, Romance, ...   TV
#
#                                         related_anime
# 0   [{'anime_id': 18397, 'relation': 'Side story'}...
# 1   [{'anime_id': 121, 'relation': 'Alternative ve...
# 2   [{'anime_id': 8408, 'relation': 'Side story'},...
# 5   [{'anime_id': 6163, 'relation': 'Summary'}, {'...
# 6   [{'anime_id': 5, 'relation': 'Side story'}, {'...
# 7   [{'anime_id': 9366, 'relation': 'Side story'},...
# 8   [{'anime_id': 17901, 'relation': 'Other'}, {'a...
# 9   [{'anime_id': 442, 'relation': 'Side story'}, ...
# 10  [{'anime_id': 10647, 'relation': 'Side story'}...
# 11  [{'anime_id': 21195, 'relation': 'Summary'}, {...
# 12  [{'anime_id': 31704, 'relation': 'Side story'}...
# 13  [{'anime_id': 27899, 'relation': 'Sequel'}, {'...
# 14  [{'anime_id': 9656, 'relation': 'Sequel'}, {'a...
# 15         [{'anime_id': 3901, 'relation': 'Sequel'}]
# 16  [{'anime_id': 16866, 'relation': 'Alternative ...
# 17                                                 []
# 18  [{'anime_id': 14353, 'relation': 'Alternative ...
# 19  [{'anime_id': 762, 'relation': 'Side story'}, ...
# 20     [{'anime_id': 9515, 'relation': 'Side story'}]
# 22  [{'anime_id': 4752, 'relation': 'Sequel'}, {'a...
# 23    [{'anime_id': 10418, 'relation': 'Side story'}]
# 25  [{'anime_id': 4182, 'relation': 'Side story'},...
# 26                                                 []
# 27  [{'anime_id': 16868, 'relation': 'Sequel'}, {'...
# 28  [{'anime_id': 246, 'relation': 'Character'}, {...
# 29  [{'anime_id': 15487, 'relation': 'Other'}, {'a...
# 30  [{'anime_id': 4898, 'relation': 'Prequel'}, {'...
# 32                                                 []
# 34  [{'anime_id': 17813, 'relation': 'Other'}, {'a...
# 35        [{'anime_id': 1869, 'relation': 'Summary'}]

# %%
anime

# %%
Y = np.random.rand(2000000, 10)

# %%
(Y.T @ Y).shape
# Out:
# (10, 10)

# %%
np.matmul?
# Out:
# Call signature:  np.matmul(*args, **kwargs)
# Type:            ufunc
# String form:     <ufunc 'matmul'>
# File:            ~/opt/anaconda3/lib/python3.8/site-packages/numpy/__init__.py
# Docstring:
# matmul(x1, x2, /, out=None, *, casting='same_kind', order='K', dtype=None, subok=True[, signature, extobj])
#
# Matrix product of two arrays.
#
# Parameters
# ----------
# x1, x2 : array_like
#     Input arrays, scalars not allowed.
# out : ndarray, optional
#     A location into which the result is stored. If provided, it must have
#     a shape that matches the signature `(n,k),(k,m)->(n,m)`. If not
#     provided or None, a freshly-allocated array is returned.
# **kwargs
#     For other keyword-only arguments, see the
#     :ref:`ufunc docs <ufuncs.kwargs>`.
#
#     .. versionadded:: 1.16
#        Now handles ufunc kwargs
#
# Returns
# -------
# y : ndarray
#     The matrix product of the inputs.
#     This is a scalar only when both x1, x2 are 1-d vectors.
#
# Raises
# ------
# ValueError
#     If the last dimension of `x1` is not the same size as
#     the second-to-last dimension of `x2`.
#
#     If a scalar value is passed in.
#
# See Also
# --------
# vdot : Complex-conjugating dot product.
# tensordot : Sum products over arbitrary axes.
# einsum : Einstein summation convention.
# dot : alternative matrix product with different broadcasting rules.
#
# Notes
# -----
#
# The behavior depends on the arguments in the following way.
#
# - If both arguments are 2-D they are multiplied like conventional
#   matrices.
# - If either argument is N-D, N > 2, it is treated as a stack of
#   matrices residing in the last two indexes and broadcast accordingly.
# - If the first argument is 1-D, it is promoted to a matrix by
#   prepending a 1 to its dimensions. After matrix multiplication
#   the prepended 1 is removed.
# - If the second argument is 1-D, it is promoted to a matrix by
#   appending a 1 to its dimensions. After matrix multiplication
#   the appended 1 is removed.
#
# ``matmul`` differs from ``dot`` in two important ways:
#
# - Multiplication by scalars is not allowed, use ``*`` instead.
# - Stacks of matrices are broadcast together as if the matrices
#   were elements, respecting the signature ``(n,k),(k,m)->(n,m)``:
#
#   >>> a = np.ones([9, 5, 7, 4])
#   >>> c = np.ones([9, 5, 4, 3])
#   >>> np.dot(a, c).shape
#   (9, 5, 7, 9, 5, 3)
#   >>> np.matmul(a, c).shape
#   (9, 5, 7, 3)
#   >>> # n is 7, k is 4, m is 3
#
# The matmul function implements the semantics of the `@` operator introduced
# in Python 3.5 following PEP465.
#
# Examples
# --------
# For 2-D arrays it is the matrix product:
#
# >>> a = np.array([[1, 0],
# ...               [0, 1]])
# >>> b = np.array([[4, 1],
# ...               [2, 2]])
# >>> np.matmul(a, b)
# array([[4, 1],
#        [2, 2]])
#
# For 2-D mixed with 1-D, the result is the usual.
#
# >>> a = np.array([[1, 0],
# ...               [0, 1]])
# >>> b = np.array([1, 2])
# >>> np.matmul(a, b)
# array([1, 2])
# >>> np.matmul(b, a)
# array([1, 2])
#
#
# Broadcasting is conventional for stacks of arrays
#
# >>> a = np.arange(2 * 2 * 4).reshape((2, 2, 4))
# >>> b = np.arange(2 * 2 * 4).reshape((2, 4, 2))
# >>> np.matmul(a,b).shape
# (2, 2, 2)
# >>> np.matmul(a, b)[0, 1, 1]
# 98
# >>> sum(a[0, 1, :] * b[0 , :, 1])
# 98
#
# Vector, vector returns the scalar inner product, but neither argument
# is complex-conjugated:
#
# >>> np.matmul([2j, 3j], [2j, 3j])
# (-13+0j)
#
# Scalar multiplication raises an error.
#
# >>> np.matmul([1,2], 3)
# Traceback (most recent call last):
# ...
# ValueError: matmul: Input operand 1 does not have enough dimensions ...
#
# The ``@`` operator can be used as a shorthand for ``np.matmul`` on
# ndarrays.
#
# >>> x1 = np.array([2j, 3j])
# >>> x2 = np.array([2j, 3j])
# >>> x1 @ x2
# (-13+0j)
#
# .. versionadded:: 1.10.0
# Class docstring:
# Functions that operate element by element on whole arrays.
#
# To see the documentation for a specific ufunc, use `info`.  For
# example, ``np.info(np.sin)``.  Because ufuncs are written in C
# (for speed) and linked into Python with NumPy's ufunc facility,
# Python's help() function finds this page whenever help() is called
# on a ufunc.
#
# A detailed explanation of ufuncs can be found in the docs for :ref:`ufuncs`.
#
# **Calling ufuncs:** ``op(*x[, out], where=True, **kwargs)``
#
# Apply `op` to the arguments `*x` elementwise, broadcasting the arguments.
#
# The broadcasting rules are:
#
# * Dimensions of length 1 may be prepended to either array.
# * Arrays may be repeated along dimensions of length 1.
#
# Parameters
# ----------
# *x : array_like
#     Input arrays.
# out : ndarray, None, or tuple of ndarray and None, optional
#     Alternate array object(s) in which to put the result; if provided, it
#     must have a shape that the inputs broadcast to. A tuple of arrays
#     (possible only as a keyword argument) must have length equal to the
#     number of outputs; use None for uninitialized outputs to be
#     allocated by the ufunc.
# where : array_like, optional
#     This condition is broadcast over the input. At locations where the
#     condition is True, the `out` array will be set to the ufunc result.
#     Elsewhere, the `out` array will retain its original value.
#     Note that if an uninitialized `out` array is created via the default
#     ``out=None``, locations within it where the condition is False will
#     remain uninitialized.
# **kwargs
#     For other keyword-only arguments, see the :ref:`ufunc docs <ufuncs.kwargs>`.
#
# Returns
# -------
# r : ndarray or tuple of ndarray
#     `r` will have the shape that the arrays in `x` broadcast to; if `out` is
#     provided, it will be returned. If not, `r` will be allocated and
#     may contain uninitialized values. If the function has more than one
#     output, then the result will be a tuple of arrays.
