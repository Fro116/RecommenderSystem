# %% [markdown]
# # Generalized Neural Network
# * See `ItemCollaborativeFiltering.Base.ipynb` for algorithm details

# %%
const name = "GNN.Rating"
const residual_alphas = ["UserItemBiases"]
const train_implicit_model = false;
const num_seeds = 5;

# %%
using NBInclude
@nbinclude("GNN.Base.ipynb");
# Out:
# Progress: 100%|███████████████████████████| Time: 0:00:07 ( 0.54 μs/it)
# Progress: 100%|███████████████████████████| Time: 0:00:04 ( 0.45 μs/it)
# Progress: 100%|███████████████████████████| Time: 0:00:04 ( 0.48 μs/it)

# %%
fit(num_seeds, 2)
# Out:
# ┌ Info: 20220407 04:38:59 The GPU function is being called but the GPU is not accessible.
# └ Defaulting back to the CPU. (No action is required if you want to run on the CPU).
# Progress: 100%|█████████████████████████████████████████| Time: 0:01:12
# Progress: 100%|█████████████████████████████████████████| Time: 0:01:02
# [ Debug: 20220407 04:41:58 iteration: 0
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:05
# [ Debug: 20220407 04:42:04 training losses: 1.6480113 -> 0.99193734
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:27
# [ Debug: 20220407 04:42:32 validation losses: 1.7552665 -> 1.0055697
# [ Debug: 20220407 04:52:44 iteration: 663
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:06
# [ Debug: 20220407 04:52:51 training losses: 1.3880116 -> 0.8354436
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:29
# [ Debug: 20220407 04:53:20 validation losses: 1.5687906 -> 0.9948867321014404
# ...
