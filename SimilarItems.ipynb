# %%
import functools
import pickle
import random

import numpy as np
import pandas as pd
import scipy.stats as st
import statsmodels.formula.api as smf


@functools.wraps(smf.ols)
def lm(*args, **kwargs):
    return smf.ols(*args, **kwargs).fit()

# %%
anime = pd.read_csv("AnimeList.csv")
anime = anime[["anime_id", "title", "type", "episodes", "genre", "studio"]]

# %%
correlations = pickle.load(open("item_correlations/correlations.pkl", "rb"))

# %%
def get_similar_shows(anime_id):
    return (
        correlations.xs(anime_id, level="anime_id_x")
        .merge(anime, left_on="anime_id_y", right_on="anime_id")
        .sort_values(by="corr", ascending=False)
    )

# %%
anime_ids = [
    1887,
    9756,
]

# %%
for anime_id in reversed(anime_ids):
    display(anime.set_index("anime_id").loc[[anime_id]])
    display(get_similar_shows(anime_id).loc[lambda x: x['type'] == 'TV'][:10])
# Out:
#                                title type  episodes  \
# anime_id
# 9756      Mahou Shoujo Madoka★Magica   TV        12
#
#                                           genre studio
# anime_id
# 9756      Drama, Magic, Psychological, Thriller  Shaft
#            corr  anime_id                             title type  episodes  \
# 12034  1.000000      9756        Mahou Shoujo Madoka★Magica   TV        12
# 12030  0.145535     11741              Fate/Zero 2nd Season   TV        12
# 12029  0.138700      5081                    Bakemonogatari   TV        15
# 12028  0.137951     10087                         Fate/Zero   TV        13
# 12027  0.135488      9253                       Steins;Gate   TV        24
# 12025  0.129061     17074  Monogatari Series: Second Season   TV        26
# 12024  0.114859     13125                    Shinsekai yori   TV        25
# 12023  0.106131     18679                      Kill la Kill   TV        24
# 12022  0.103652      2001        Tengen Toppa Gurren Lagann   TV        27
# 12021  0.102794     15689              Nekomonogatari: Kuro   TV         4
#
#                                                    genre        studio
# 12034              Drama, Magic, Psychological, Thriller         Shaft
# 12030               Action, Supernatural, Magic, Fantasy      ufotable
# 12029            Romance, Supernatural, Mystery, Vampire         Shaft
# 12028               Action, Supernatural, Magic, Fantasy      ufotable
# 12027                                   Thriller, Sci-Fi     White Fox
# 12025    Mystery, Comedy, Supernatural, Romance, Vampire         Shaft
# 12024  Sci-Fi, Mystery, Horror, Psychological, Supern...  A-1 Pictures
# 12023         Action, Comedy, Super Power, Ecchi, School       Trigger
# 12022           Action, Adventure, Comedy, Mecha, Sci-Fi        Gainax
# 12021               Comedy, Supernatural, Romance, Ecchi         Shaft
#                title type  episodes                                  genre  \
# anime_id
# 1887      Lucky☆Star   TV        24  Slice of Life, Comedy, Parody, School
#
#                    studio
# anime_id
# 1887      Kyoto Animation
#            corr  anime_id                              title type  episodes  \
# 11849  0.149973       849         Suzumiya Haruhi no Yuuutsu   TV        14
# 11848  0.148114      5680                              K-On!   TV        13
# 11847  0.108612        66                     Azumanga Daioh   TV        26
# 11846  0.096348      7791                             K-On!!   TV        26
# 11845  0.081279      2963                          Minami-ke   TV        13
# 11844  0.071617      2167                            Clannad   TV        23
# 11843  0.069738      1530                       Kanon (2006)   TV        24
# 11842  0.067201      4382  Suzumiya Haruhi no Yuuutsu (2009)   TV        14
# 11840  0.063695     10165                           Nichijou   TV        26
# 11839  0.063001       488                   Ichigo Mashimaro   TV        12
#
#                                                    genre           studio
# 11849  Comedy, Mystery, Parody, School, Sci-Fi, Slice...  Kyoto Animation
# 11848               Slice of Life, Comedy, Music, School  Kyoto Animation
# 11847                      Slice of Life, Comedy, School        J.C.Staff
# 11846               Comedy, Music, School, Slice of Life  Kyoto Animation
# 11845                      Slice of Life, Comedy, School            Daume
# 11844  Slice of Life, Comedy, Romance, Supernatural, ...  Kyoto Animation
# 11843        Slice of Life, Supernatural, Drama, Romance  Kyoto Animation
# 11842  Sci-Fi, Slice of Life, Mystery, Comedy, Parody...  Kyoto Animation
# 11840                      Slice of Life, Comedy, School  Kyoto Animation
# 11839                              Slice of Life, Comedy            Daume

# %%
for anime_id in reversed(anime_ids):
    display(anime.set_index("anime_id").loc[[anime_id]])
    display(get_similar_shows(anime_id)[:10])
# Out:
#                                title type  episodes  \
# anime_id
# 9756      Mahou Shoujo Madoka★Magica   TV        12
#
#                                           genre studio
# anime_id
# 9756      Drama, Magic, Psychological, Thriller  Shaft
#            corr  anime_id                                              title  \
# 12034  1.000000      9756                         Mahou Shoujo Madoka★Magica
# 12033  0.246689     11979  Mahou Shoujo Madoka★Magica Movie 2: Eien no Mo...
# 12032  0.246053     11977  Mahou Shoujo Madoka★Magica Movie 1: Hajimari n...
# 12031  0.245492     11981  Mahou Shoujo Madoka★Magica Movie 3: Hangyaku n...
# 12030  0.145535     11741                               Fate/Zero 2nd Season
# 12029  0.138700      5081                                     Bakemonogatari
# 12028  0.137951     10087                                          Fate/Zero
# 12027  0.135488      9253                                        Steins;Gate
# 12026  0.130465      7311                      Suzumiya Haruhi no Shoushitsu
# 12025  0.129061     17074                   Monogatari Series: Second Season
#
#         type  episodes                                              genre  \
# 12034     TV        12              Drama, Magic, Psychological, Thriller
# 12033  Movie         1              Drama, Magic, Psychological, Thriller
# 12032  Movie         1              Psychological, Drama, Magic, Thriller
# 12031  Movie         1              Psychological, Drama, Magic, Thriller
# 12030     TV        12               Action, Supernatural, Magic, Fantasy
# 12029     TV        15            Romance, Supernatural, Mystery, Vampire
# 12028     TV        13               Action, Supernatural, Magic, Fantasy
# 12027     TV        24                                   Thriller, Sci-Fi
# 12026  Movie         1  Comedy, Mystery, Romance, School, Sci-Fi, Supe...
# 12025     TV        26    Mystery, Comedy, Supernatural, Romance, Vampire
#
#                 studio
# 12034            Shaft
# 12033            Shaft
# 12032            Shaft
# 12031            Shaft
# 12030         ufotable
# 12029            Shaft
# 12028         ufotable
# 12027        White Fox
# 12026  Kyoto Animation
# 12025            Shaft
#                title type  episodes                                  genre  \
# anime_id
# 1887      Lucky☆Star   TV        24  Slice of Life, Comedy, Parody, School
#
#                    studio
# anime_id
# 1887      Kyoto Animation
#            corr  anime_id                                        title   type  \
# 11850  0.288862      4472  Lucky☆Star: Original na Visual to Animation    OVA
# 11849  0.149973       849                   Suzumiya Haruhi no Yuuutsu     TV
# 11848  0.148114      5680                                        K-On!     TV
# 11847  0.108612        66                               Azumanga Daioh     TV
# 11846  0.096348      7791                                       K-On!!     TV
# 11845  0.081279      2963                                    Minami-ke     TV
# 11844  0.071617      2167                                      Clannad     TV
# 11843  0.069738      1530                                 Kanon (2006)     TV
# 11842  0.067201      4382            Suzumiya Haruhi no Yuuutsu (2009)     TV
# 11841  0.064697      7311                Suzumiya Haruhi no Shoushitsu  Movie
#
#        episodes                                              genre  \
# 11850         1              Comedy, Parody, School, Slice of Life
# 11849        14  Comedy, Mystery, Parody, School, Sci-Fi, Slice...
# 11848        13               Slice of Life, Comedy, Music, School
# 11847        26                      Slice of Life, Comedy, School
# 11846        26               Comedy, Music, School, Slice of Life
# 11845        13                      Slice of Life, Comedy, School
# 11844        23  Slice of Life, Comedy, Romance, Supernatural, ...
# 11843        24        Slice of Life, Supernatural, Drama, Romance
# 11842        14  Sci-Fi, Slice of Life, Mystery, Comedy, Parody...
# 11841         1  Comedy, Mystery, Romance, School, Sci-Fi, Supe...
#
#                 studio
# 11850  Kyoto Animation
# 11849  Kyoto Animation
# 11848  Kyoto Animation
# 11847        J.C.Staff
# 11846  Kyoto Animation
# 11845            Daume
# 11844  Kyoto Animation
# 11843  Kyoto Animation
# 11842  Kyoto Animation
# 11841  Kyoto Animation
